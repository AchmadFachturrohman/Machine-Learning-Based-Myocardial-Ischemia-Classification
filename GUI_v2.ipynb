# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
import itertools

from tkinter import *
from tkinter import ttk
from tkinter.filedialog import askopenfilename
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from PIL import Image,ImageTk
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.metrics import confusion_matrix, classification_report
import math

# %%
root = Tk()
root.geometry("1360x768")
root.maxsize(1300, 630)
root['bg']= '#49A'

# %%
bg_app_raw = Image.open("D:/Pictures/81116.jpg")

# Resize the image in the given (width, height)
img_app_raw=bg_app_raw.resize((1360, 800))

# Conver the image in TkImage
bg_app = ImageTk.PhotoImage(img_app_raw)
#bg_app = PhotoImage(file="E:/KULIAHKULIAH/Sem 8/TA/Background app/579139.png")

cnvs1 = Canvas(root, width=900, height=800)
cnvs1.pack(fill="both")
cnvs1.create_image(0,0, image=bg_app, anchor ="nw")

# Declaration of Additional Variable
cnvs1.create_text(650,35, text=" Machine Learning Based Myocardial Ishcemia Classifications  ", fill='white', font=('times', 20, 'bold'))

#Add Logo ITS
image1 = Image.open("D:/Pictures/Logo-ITS-Institut-Teknologi-Sepuluh-November-Original.png")
image1 = image1.resize((150,150))
logo1 = ImageTk.PhotoImage(image1)
cnvs1.create_image(20, 20, anchor="nw", image=logo1)

#Add Logo BME
image2 = Image.open("D:/Pictures/bme logo.png")
image2 = image2.resize((130,130))
logo2 = ImageTk.PhotoImage(image2)
cnvs1.create_image(1140, 25, anchor="nw", image=logo2)
# Out:
# 4

# %%
base_frame = Frame(root, width= 800, height=500)
base_frame.place(x=240, y=60)

notebook = ttk.Notebook(base_frame)
notebook.pack()

frame1 = ttk.Frame(notebook, width=800, height=500)
frame1.pack()
frame1.pack_propagate(0)
notebook.add(frame1, text='Input')

frame2 = ttk.Frame(notebook, width=800, height=500)
frame2.pack()
frame2.pack_propagate(0)
notebook.add(frame2, text='Training')

frame3 = ttk.Frame(notebook, width=800, height=500)
frame3.pack()
frame3.pack_propagate(0)
notebook.add(frame3, text='Testing')

# %%
def OpenFile():
    global data_frame
    data_frame = askopenfilename(initialdir="G:/Semester 8/TA/DWT/Win32/Debug", title="Select A File", filetypes=(("csv files", "*.csv"),("all files", "*.*")))
    data_frame = pd.read_csv(data_frame, header=None)
    data_frame = data_frame.rename({250: 'Class'}, axis=1)
    var0.set("({} x {})".format(data_frame.shape[0],data_frame.shape[1]))

# %%
def SplitData():
    global X_train, Y_train, X_val, Y_val
    train_data, val_data = train_test_split(data_frame, test_size=0.15)
    
    X_train = train_data.loc[:, train_data.columns != 'Class']
    Y_train = train_data.loc[:, train_data.columns == 'Class']
    Y_train = to_categorical(Y_train)
    var1.set("X_train ({} x {})".format(X_train.shape[0],X_train.shape[1]))    
    var2.set("Y_train ({} x {})".format(Y_train.shape[0],Y_train.shape[1]))

    X_val = val_data.loc[:, val_data.columns != 'Class']
    Y_val = val_data.loc[:, val_data.columns == 'Class']
    Y_val = to_categorical(Y_val)
    var3.set("X_Val ({} x {})".format(X_val.shape[0],X_val.shape[1]))
    var4.set("Y_Val ({} x {})".format(Y_val.shape[0],Y_val.shape[1]))

    train_size = train_data['Class'].value_counts()
    fig1 = Figure(figsize=(5,5)) # create a figure object
    ax1 = fig1.add_subplot() # add an Axes to the figure
    ax1.pie(train_size, labels=['Normal','Ischemia'], colors=['blue','skyblue'],autopct='%1.1f%%',radius=1.2,textprops={'fontsize': 10})     
    pie1 = FigureCanvasTkAgg(fig1, in_frame2)
    pie1.get_tk_widget().pack(side=LEFT, fill=BOTH, expand=1)

    val_size = val_data['Class'].value_counts()
    fig2 = Figure(figsize=(5,5))
    ax2 = fig2.add_subplot() # add an Axes to the figure
    ax2.pie(val_size, labels=['Normal','Ischemia'], colors=['red','orange'],autopct='%1.1f%%',radius=1.2,textprops={'fontsize': 10})     
    pie2 = FigureCanvasTkAgg(fig2, in_frame2)
    pie2.get_tk_widget().pack(side=LEFT, fill=BOTH, expand=1)

    Label7 = Label(in_frame3, text=" Data Size Training ", bg="white")
    Label7.pack(side=LEFT, ipadx=147)
    Label8 = Label(in_frame3, text=" Data Size Validation ", bg="white")
    Label8.pack(side=LEFT, ipadx=147)

# %%
def Training():
    global ann_model
    ann_model = Sequential()
    ann_model.add(Dense(32, activation='relu', input_shape=(250,)))
    ann_model.add(Dense(24, activation='relu'))
    ann_model.add(Dense(2, activation='softmax'))
    ann_model.summary()    
    
    ann_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    #my_callbacks = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
    
    epocs = 300   
    class myCallback(tf.keras.callbacks.Callback):
        def on_epoch_begin(self, epoch, logs={}):
            speed = 1
            pbar['value'] += (speed/epocs)*100                
            percentLabel.config(text=str(math.ceil(pbar['value'])) + "%")                                                  
            in_frame1_21.update_idletasks()            
    my_callbacks = myCallback()

    history = ann_model.fit(
        X_train,Y_train,
        validation_data=(X_val, Y_val),
        batch_size=32,
        epochs=epocs,
        callbacks=[my_callbacks]
    )   

    taskLabel.config(text="Completed !")

    my_acc = history.history['accuracy']
    my_val_acc = history.history['val_accuracy']

    # plot accuracy
    fig3 = Figure(figsize=(5, 5))
    ax3 = fig3.add_subplot()    
    ax3.set_title('Training Accuracy')    
    ax3.set_ylabel('Accuracy')
    ax3.set_xlabel('Epochs')
    ax3.set_ylim([min(ax3.set_ylim()),1])
    ax3.plot(my_acc, label='Training')
    ax3.plot(my_val_acc, label='Validation')  
    ax3.legend(loc='lower right') 
    line1 = FigureCanvasTkAgg(fig3, in_frame1_23)
    line1.get_tk_widget().pack(side=LEFT, fill=BOTH, expand=1)    

    # visualize the loss training history
    my_loss = history.history['loss']
    my_val_loss = history.history['val_loss']

    # plot loss
    fig4 = Figure(figsize=(5, 5))
    ax4 = fig4.add_subplot()
    ax4.set_title('Training Loss')
    ax4.set_ylabel('Loss')
    ax4.set_xlabel('Epochs')    
    ax4.set_ylim([min(ax4.set_ylim()),1])
    ax4.plot(my_loss, label='Training')
    ax4.plot(my_val_loss, label='Validation')
    ax4.legend(loc='lower left')
    line2 = FigureCanvasTkAgg(fig4, in_frame1_23)
    line2.get_tk_widget().pack(side=LEFT, fill=BOTH, expand=1)

# %%
def OpenDataTest():
     global test_data
     test_data = askopenfilename(initialdir="G:/Semester 8/TA/DWT/Win32/Debug", title="Select A File", filetypes=(("csv files", "*.csv"),("all files", "*.*")))
     test_data = pd.read_csv(test_data, header=None)
     test_data = test_data.rename({250: 'Class'}, axis=1)
     var5.set("({} x {})".format(test_data.shape[0],test_data.shape[1]))

# %%
def SplitDataTest():
    global X_test, Y_test
    X_test = test_data.loc[:, test_data.columns != 'Class']
    Y_test = test_data.loc[:, test_data.columns == 'Class']
    Y_test = to_categorical(Y_test)
    var6.set("X_test ({} x {})".format(X_test.shape[0],X_test.shape[1]))
    var7.set("Y_test ({} x {})".format(Y_test.shape[0],Y_test.shape[1]))

    test_size = test_data['Class'].value_counts()
    fig5 = Figure(figsize=(5,5))
    ax5 = fig5.add_subplot() # add an Axes to the figure
    ax5.pie(test_size, labels=['Normal','Ischemia'], colors=['green','lightgreen'],autopct='%1.1f%%',radius=1.2,textprops={'fontsize': 10})     
    pie3 = FigureCanvasTkAgg(fig5, in_frame2_3_1)
    pie3.get_tk_widget().pack(side=TOP, expand=1)

    Label8 = Label(in_frame2_3_1, text=" Data Size Training ", bg="white")
    Label8.pack(side=TOP, ipadx=147)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    print(' ')

    fig6 = Figure(figsize=(5,5))
    ax6 = fig6.add_subplot()
    ax6.imshow(cm, interpolation='nearest', cmap=cmap)
    ax6.set_title(title)
    #ax6.colorbar()
    tick_marks = np.arange(len(classes))
    #ax6.set_xticklabels(tick_marks, classes)
    #ax6.set_yticklabels(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        ax6.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    ax6.set_ylabel('True label')
    ax6.set_xlabel('Classified label')
    #ax6.tight_layout()
    confusion_chart = FigureCanvasTkAgg(fig6, in_frame2_3_2)
    confusion_chart.get_tk_widget().pack(side=TOP, padx=5, expand=1)

# %%
def TestingModel():
    hasil_evaluasi = ann_model.evaluate(X_test, Y_test, batch_size=32)
    var8.set("Accuracy : {:.2f}%".format(hasil_evaluasi[1] * 100))
    var9.set("Loss : {:.2f}%".format(hasil_evaluasi[0] * 100))

    Y_pred = ann_model.predict(X_test)
    Y_pred = np.argmax(Y_pred,axis=1)
    Y_true = np.argmax(Y_test,axis=1)
    cm = confusion_matrix(Y_true,Y_pred)
    plot_confusion_matrix(cm, classes=['Normal', 'Ischemia'])  
    print(type(classification_report(Y_true,Y_pred)))

# %%
#Frame1 "Input" Menu
in_frame1 = Frame(frame1, width=800, height=60, bg="white")
in_frame1.pack()
in_frame1.pack_propagate(0)

var0 = StringVar()
var1 = StringVar()
var2 = StringVar()
var3 = StringVar()
var4 = StringVar()

btn1 = Button(in_frame1, text="Load File", command=OpenFile)
btn1.pack(side=LEFT, ipadx=5, padx=20)
btn2 = Button(in_frame1, text="Split Data", command=SplitData)
btn2.pack(side=LEFT, ipadx=5, padx=20)

box0  = LabelFrame(in_frame1, text="Dataset Frame", bg="white")
box0.pack(side=LEFT, padx=5)
Label0 = Label(box0, text="", textvariable=var0, bg="white")
Label0.pack(side=TOP)

box1  = LabelFrame(in_frame1, text="Training Data Frame", bg="white")
box1.pack(side=LEFT, padx=5)
Label1 = Label(box1, text="", textvariable=var1, bg="white")
Label1.pack(side=TOP)
Label2 = Label(box1, text="", textvariable=var2, bg="white")
Label2.pack(side=TOP)

box2  = LabelFrame(in_frame1, text="Validation Data Frame", bg="white")
box2.pack(side=LEFT, padx=5)
Label3 = Label(box2, text="", textvariable=var3, bg="white")
Label3.pack(side=TOP)
Label4 = Label(box2, text="", textvariable=var4, bg="white")
Label4.pack(side=TOP)

in_frame2 = Frame(frame1, width=800, height=400, bg="white")
in_frame2.pack(side=TOP)
in_frame2.pack_propagate(0)

in_frame3 = Frame(frame1, width=800, height=40, bg="white")
in_frame3.pack(side=TOP)
in_frame3.pack_propagate(0)

# %%
#FRAME 2 "Training" Menu

in_frame1_2 = Frame(frame2, width=800, height=40, bg="white")
in_frame1_2.pack()
in_frame1_2.pack_propagate(0)

btn3 = Button(in_frame1_2, text="Training Model", command=Training)
btn3.pack(side=LEFT, padx=15)

in_frame1_21 = Frame(in_frame1_2, width=700, height=40, bg="white")
in_frame1_21.pack(side=RIGHT)
in_frame1_21.pack_propagate(0)

pbar = ttk.Progressbar(in_frame1_21,orient = HORIZONTAL,length = 700, mode = 'determinate')
pbar.pack(side=LEFT)

in_frame1_22 = Frame(frame2, width=800, height=20, bg="white")
in_frame1_22.pack()
in_frame1_22.pack_propagate(0)

in_frame1_22_1 = Frame(in_frame1_22, width=400, height=20, bg="white")
in_frame1_22_1.pack(side=LEFT)
in_frame1_22_1.pack_propagate(0)

in_frame1_22_2 = Frame(in_frame1_22, width=400, height=20, bg="white")
in_frame1_22_2.pack(side=LEFT)
in_frame1_22_2.pack_propagate(0)

percentLabel = Label(in_frame1_22_1, bg="white")
percentLabel.pack(side=RIGHT)

taskLabel = Label(in_frame1_22_2, bg="white")
taskLabel.pack(side=LEFT)

in_frame1_23 = Frame(frame2, width=800, height=440, bg="white")
in_frame1_23.pack()
in_frame1_23.pack_propagate(0)

# %%
#Frame 3 "Testing" Menu

in_frame1_3 = Frame(frame3, width=800, height=60, bg="white")
in_frame1_3.pack()
in_frame1_3.pack_propagate(0)

btn4 = Button(in_frame1_3, text="Load Data Test", command=OpenDataTest)
btn4.pack(side=LEFT, ipadx=5, padx=20)
btn5 = Button(in_frame1_3, text="Split Data", command=SplitDataTest)
btn5.pack(side=LEFT, ipadx=5, padx=20)
btn6 = Button(in_frame1_3, text="Testing", command=TestingModel)
btn6.pack(side=LEFT, ipadx=5, padx=20)

var5 = StringVar()
var6 = StringVar()
var7 = StringVar()
var8 = StringVar()
var9 = StringVar()

box3  = LabelFrame(in_frame1_3, text="Data Test Frame", bg="white")
box3.pack(side=LEFT, padx=10)
Label5 = Label(box3, text="", textvariable=var5, bg="white")
Label5.pack(side=TOP)

box4  = LabelFrame(in_frame1_3, text="Testing Data Frame", bg="white")
box4.pack(side=LEFT, padx=10)
Label6 = Label(box4, textvariable=var6, bg="white")
Label6.pack(side=TOP)
Label7 = Label(box4, textvariable=var7, bg="white")
Label7.pack(side=TOP)

box5  = LabelFrame(in_frame1_3, text="Testing Result", bg="white")
box5.pack(side=LEFT, padx=10)
Label9 = Label(box5, textvariable=var8, bg="white")
Label9.pack(side=TOP)
Label10 = Label(box5, textvariable=var9, bg="white")
Label10.pack(side=TOP)

in_frame2_3 = Frame(frame3, width=800, height=440)
in_frame2_3.pack()
in_frame2_3.pack_propagate(0)

in_frame2_3_1 = Frame(in_frame2_3, width=400, height=440, bg="white")
in_frame2_3_1.pack(side=LEFT)
in_frame2_3_1.pack_propagate(0)

in_frame2_3_2 = Frame(in_frame2_3, width=400, height=440, bg="white")
in_frame2_3_2.pack(side=LEFT)
in_frame2_3_2.pack_propagate(0)

# %%
root.mainloop()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                8032
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                792
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 8,874
# Trainable params: 8,874
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 83/83 [==============================] - 2s 9ms/step - loss: 0.7368 - accuracy: 0.4363 - val_loss: 0.7494 - val_accuracy: 0.4368
# Epoch 2/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7322 - accuracy: 0.4382 - val_loss: 0.7452 - val_accuracy: 0.4433
# Epoch 3/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7279 - accuracy: 0.4450 - val_loss: 0.7413 - val_accuracy: 0.4411
# Epoch 4/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7239 - accuracy: 0.4560 - val_loss: 0.7376 - val_accuracy: 0.4325
# Epoch 5/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.7201 - accuracy: 0.4616 - val_loss: 0.7342 - val_accuracy: 0.4390
# Epoch 6/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7167 - accuracy: 0.4749 - val_loss: 0.7312 - val_accuracy: 0.4433
# Epoch 7/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7134 - accuracy: 0.4836 - val_loss: 0.7283 - val_accuracy: 0.4518
# Epoch 8/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7104 - accuracy: 0.4866 - val_loss: 0.7255 - val_accuracy: 0.4582
# Epoch 9/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7076 - accuracy: 0.4960 - val_loss: 0.7230 - val_accuracy: 0.4711
# Epoch 10/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7050 - accuracy: 0.5025 - val_loss: 0.7208 - val_accuracy: 0.4711
# Epoch 11/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7025 - accuracy: 0.5112 - val_loss: 0.7186 - val_accuracy: 0.4775
# Epoch 12/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.7002 - accuracy: 0.5164 - val_loss: 0.7168 - val_accuracy: 0.4839
# Epoch 13/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6981 - accuracy: 0.5251 - val_loss: 0.7150 - val_accuracy: 0.4861
# Epoch 14/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6961 - accuracy: 0.5316 - val_loss: 0.7133 - val_accuracy: 0.4904
# Epoch 15/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6942 - accuracy: 0.5342 - val_loss: 0.7118 - val_accuracy: 0.4989
# Epoch 16/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6924 - accuracy: 0.5369 - val_loss: 0.7104 - val_accuracy: 0.4946
# Epoch 17/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6908 - accuracy: 0.5440 - val_loss: 0.7091 - val_accuracy: 0.4882
# Epoch 18/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6892 - accuracy: 0.5425 - val_loss: 0.7079 - val_accuracy: 0.4797
# Epoch 19/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6877 - accuracy: 0.5474 - val_loss: 0.7068 - val_accuracy: 0.4861
# Epoch 20/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6863 - accuracy: 0.5565 - val_loss: 0.7058 - val_accuracy: 0.4946
# Epoch 21/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6850 - accuracy: 0.5614 - val_loss: 0.7048 - val_accuracy: 0.5011
# Epoch 22/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6838 - accuracy: 0.5652 - val_loss: 0.7040 - val_accuracy: 0.5096
# Epoch 23/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.
300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6040 - accuracy: 0.6979 - val_loss: 0.6943 - val_accuracy: 0.5717
# Epoch 182/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6035 - accuracy: 0.6979 - val_loss: 0.6943 - val_accuracy: 0.5717
# Epoch 183/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6030 - accuracy: 0.6983 - val_loss: 0.6944 - val_accuracy: 0.5717
# Epoch 184/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6025 - accuracy: 0.6979 - val_loss: 0.6945 - val_accuracy: 0.5717
# Epoch 185/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6020 - accuracy: 0.6975 - val_loss: 0.6945 - val_accuracy: 0.5696
# Epoch 186/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6016 - accuracy: 0.6987 - val_loss: 0.6946 - val_accuracy: 0.5696
# Epoch 187/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6010 - accuracy: 0.6991 - val_loss: 0.6946 - val_accuracy: 0.5696
# Epoch 188/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6006 - accuracy: 0.6994 - val_loss: 0.6947 - val_accuracy: 0.5717
# Epoch 189/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6000 - accuracy: 0.7002 - val_loss: 0.6948 - val_accuracy: 0.5739
# Epoch 190/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5996 - accuracy: 0.7002 - val_loss: 0.6948 - val_accuracy: 0.5717
# Epoch 191/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5991 - accuracy: 0.7025 - val_loss: 0.6949 - val_accuracy: 0.5717
# Epoch 192/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5986 - accuracy: 0.7025 - val_loss: 0.6950 - val_accuracy: 0.5717
# Epoch 193/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5980 - accuracy: 0.7043 - val_loss: 0.6950 - val_accuracy: 0.5717
# Epoch 194/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5975 - accuracy: 0.7051 - val_loss: 0.6951 - val_accuracy: 0.5696
# Epoch 195/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5970 - accuracy: 0.7051 - val_loss: 0.6952 - val_accuracy: 0.5717
# Epoch 196/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5966 - accuracy: 0.7051 - val_loss: 0.6952 - val_accuracy: 0.5717
# Epoch 197/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5960 - accuracy: 0.7062 - val_loss: 0.6953 - val_accuracy: 0.5717
# Epoch 198/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5955 - accuracy: 0.7062 - val_loss: 0.6954 - val_accuracy: 0.5717
# Epoch 199/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5950 - accuracy: 0.7066 - val_loss: 0.6954 - val_accuracy: 0.5717
# Epoch 200/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5945 - accuracy: 0.7074 - val_loss: 0.6955 - val_accuracy: 0.5696
# Epoch 201/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5940 - accuracy: 0.7078 - val_loss: 0.6956 - val_accuracy: 0.5696
# Epoch 202/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5935 - accuracy: 0.7093 - val_loss: 0.6957 - val_accuracy: 0.5696
# Epoch 203/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5930 - accuracy: 0.7096 - val_loss: 0.6957 - val_accuracy: 0.5675
# Epoch 204/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5924 - accuracy: 0.7093 - val_loss: 0.6958 - val_accuracy: 0.5696
# Epoch 205/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5919 - accuracy: 0.7100 - val_loss: 0.6959 - val_accuracy: 0.5717
# Epoch 206/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5914 - accuracy: 0.7104 - val_loss: 0.6960 - val_accuracy: 0.5717
# Epoch 207/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5909 - accuracy: 0.7108 - val_loss: 0.6960 - val_accuracy: 0.5717
# Epoch 208/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5904 - accuracy: 0.7108 - val_loss: 0.6961 - val_accuracy: 0.5696
# Epoch 209/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5899 - accuracy: 0.7115 - val_loss: 0.6962 - val_accuracy: 0.5717
# Epoch 210/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5893 - accuracy: 0.7127 - val_loss: 0.6963 - val_accuracy: 0.5717
# Epoch 211/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.
300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5727 - accuracy: 0.7327 - val_loss: 0.6990 - val_accuracy: 0.5653
# Epoch 242/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5721 - accuracy: 0.7353 - val_loss: 0.6991 - val_accuracy: 0.5653
# Epoch 243/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5716 - accuracy: 0.7357 - val_loss: 0.6992 - val_accuracy: 0.5653
# Epoch 244/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5710 - accuracy: 0.7365 - val_loss: 0.6993 - val_accuracy: 0.5653
# Epoch 245/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5704 - accuracy: 0.7369 - val_loss: 0.6994 - val_accuracy: 0.5653
# Epoch 246/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5699 - accuracy: 0.7369 - val_loss: 0.6995 - val_accuracy: 0.5653
# Epoch 247/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5693 - accuracy: 0.7372 - val_loss: 0.6997 - val_accuracy: 0.5632
# Epoch 248/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5688 - accuracy: 0.7376 - val_loss: 0.6997 - val_accuracy: 0.5653
# Epoch 249/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5682 - accuracy: 0.7384 - val_loss: 0.6999 - val_accuracy: 0.5632
# Epoch 250/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5677 - accuracy: 0.7391 - val_loss: 0.7000 - val_accuracy: 0.5632
# Epoch 251/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5671 - accuracy: 0.7391 - val_loss: 0.7001 - val_accuracy: 0.5632
# Epoch 252/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5665 - accuracy: 0.7399 - val_loss: 0.7001 - val_accuracy: 0.5610
# Epoch 253/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5660 - accuracy: 0.7403 - val_loss: 0.7003 - val_accuracy: 0.5610
# Epoch 254/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5654 - accuracy: 0.7406 - val_loss: 0.7004 - val_accuracy: 0.5610
# Epoch 255/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5648 - accuracy: 0.7414 - val_loss: 0.7005 - val_accuracy: 0.5610
# Epoch 256/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5643 - accuracy: 0.7414 - val_loss: 0.7006 - val_accuracy: 0.5610
# Epoch 257/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5637 - accuracy: 0.7418 - val_loss: 0.7007 - val_accuracy: 0.5610
# Epoch 258/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5631 - accuracy: 0.7422 - val_loss: 0.7008 - val_accuracy: 0.5589
# Epoch 259/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5626 - accuracy: 0.7429 - val_loss: 0.7009 - val_accuracy: 0.5589
# Epoch 260/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5620 - accuracy: 0.7429 - val_loss: 0.7011 - val_accuracy: 0.5589
# Epoch 261/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5614 - accuracy: 0.7437 - val_loss: 0.7012 - val_accuracy: 0.5632
# Epoch 262/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5609 - accuracy: 0.7440 - val_loss: 0.7013 - val_accuracy: 0.5632
# Epoch 263/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5603 - accuracy: 0.7440 - val_loss: 0.7014 - val_accuracy: 0.5632
# Epoch 264/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5597 - accuracy: 0.7452 - val_loss: 0.7015 - val_accuracy: 0.5632
# Epoch 265/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5591 - accuracy: 0.7456 - val_loss: 0.7016 - val_accuracy: 0.5632
# Epoch 266/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5586 - accuracy: 0.7463 - val_loss: 0.7017 - val_accuracy: 0.5610
# Epoch 267/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5580 - accuracy: 0.7467 - val_loss: 0.7019 - val_accuracy: 0.5610
# Epoch 268/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5574 - accuracy: 0.7463 - val_loss: 0.7020 - val_accuracy: 0.5610
# Epoch 269/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5568 - accuracy: 0.7471 - val_loss: 0.7021 - val_accuracy: 0.5610
# Epoch 270/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5562 - accuracy: 0.7478 - val_loss: 0.7022 - val_accuracy: 0.5610
# Epoch 271/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5557 - accuracy: 0.7482 - val_loss: 0.7023 - val_accuracy: 0.5610
# Epoch 272/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5551 - accuracy: 0.7482 - val_loss: 0.7024 - val_accuracy: 0.5610
# Epoch 273/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5545 - accuracy: 0.7493 - val_loss: 0.7025 - val_accuracy: 0.5610
# Epoch 274/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.5539 - accuracy: 0.7493 - val_loss: 0.7027 - val_accuracy: 0.5632
# Epoch 275/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.5533 - accuracy: 0.7505 - val_loss: 0.7028 - val_accuracy: 0.5632
# Epoch 276/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5527 - accuracy: 0.7516 - val_loss: 0.7029 - val_accuracy: 0.5610
# Epoch 277/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5522 - accuracy: 0.7516 - val_loss: 0.7030 - val_accuracy: 0.5632
# Epoch 278/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5516 - accuracy: 0.7516 - val_loss: 0.7031 - val_accuracy: 0.5632
# Epoch 279/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5510 - accuracy: 0.7527 - val_loss: 0.7033 - val_accuracy: 0.5632
# Epoch 280/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5504 - accuracy: 0.7543 - val_loss: 0.7034 - val_accuracy: 0.5610
# Epoch 281/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5498 - accuracy: 0.7554 - val_loss: 0.7035 - val_accuracy: 0.5653
# Epoch 282/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5492 - accuracy: 0.7565 - val_loss: 0.7036 - val_accuracy: 0.5653
# Epoch 283/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5486 - accuracy: 0.7577 - val_loss: 0.7037 - val_accuracy: 0.5632
# Epoch 284/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5480 - accuracy: 0.7584 - val_loss: 0.7038 - val_accuracy: 0.5653
# Epoch 285/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5474 - accuracy: 0.7592 - val_loss: 0.7040 - val_accuracy: 0.5653
# Epoch 286/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5468 - accuracy: 0.7592 - val_loss: 0.7041 - val_accuracy: 0.5653
# Epoch 287/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5462 - accuracy: 0.7614 - val_loss: 0.7042 - val_accuracy: 0.5675
# Epoch 288/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5456 - accuracy: 0.7622 - val_loss: 0.7044 - val_accuracy: 0.5675
# Epoch 289/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5450 - accuracy: 0.7629 - val_loss: 0.7045 - val_accuracy: 0.5675
# Epoch 290/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5444 - accuracy: 0.7629 - val_loss: 0.7046 - val_accuracy: 0.5653
# Epoch 291/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5438 - accuracy: 0.7641 - val_loss: 0.7048 - val_accuracy: 0.5653
# Epoch 292/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5432 - accuracy: 0.7637 - val_loss: 0.7049 - val_accuracy: 0.5675
# Epoch 293/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5426 - accuracy: 0.7645 - val_loss: 0.7050 - val_accuracy: 0.5675
# Epoch 294/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5420 - accuracy: 0.7645 - val_loss: 0.7052 - val_accuracy: 0.5675
# Epoch 295/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5414 - accuracy: 0.7652 - val_loss: 0.7053 - val_accuracy: 0.5653
# Epoch 296/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5408 - accuracy: 0.7652 - val_loss: 0.7055 - val_accuracy: 0.5653
# Epoch 297/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5402 - accuracy: 0.7660 - val_loss: 0.7056 - val_accuracy: 0.5653
# Epoch 298/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5396 - accuracy: 0.7664 - val_loss: 0.7057 - val_accuracy: 0.5653
# Epoch 299/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5390 - accuracy: 0.7667 - val_loss: 0.7059 - val_accuracy: 0.5653
# Epoch 300/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5384 - accuracy: 0.7671 - val_loss: 0.7061 - val_accuracy: 0.5653
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6578 - accuracy: 0.6339
# Confusion matrix, without normalization
# [[ 69 148]
#  [ 53 279]]
#
# <class 'str'>
