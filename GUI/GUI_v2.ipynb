# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
import itertools

from tkinter import *
from tkinter import ttk
from tkinter.filedialog import askopenfilename
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from PIL import Image,ImageTk
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.metrics import confusion_matrix, classification_report
import math

# %%
root = Tk()
root.geometry("1360x768")
root.maxsize(1300, 630)
root['bg']= '#49A'

# %%
bg_app_raw = Image.open("D:/PICTURE/Death-Is-Not-the-End.jpg")

# Resize the image in the given (width, height)
img_app_raw=bg_app_raw.resize((1360, 800))

# Conver the image in TkImage
bg_app = ImageTk.PhotoImage(img_app_raw)
#bg_app = PhotoImage(file="E:/KULIAHKULIAH/Sem 8/TA/Background app/579139.png")

cnvs1 = Canvas(root, width=900, height=800)
cnvs1.pack(fill="both")
cnvs1.create_image(0,0, image=bg_app, anchor ="nw")

# Declaration of Additional Variable
cnvs1.create_text(650,35, text=" Machine Learning Based Myocardial Ishcemia Classifications  ", fill='white', font=('times', 20, 'bold'))

#Add Logo ITS
image1 = Image.open("D:/PICTURE/Logo-ITS-Institut-Teknologi-Sepuluh-November-Original.png")
image1 = image1.resize((150,150))
logo1 = ImageTk.PhotoImage(image1)
cnvs1.create_image(20, 20, anchor="nw", image=logo1)

#Add Logo BME
image2 = Image.open("D:/PICTURE/bme logo.png")
image2 = image2.resize((130,130))
logo2 = ImageTk.PhotoImage(image2)
cnvs1.create_image(1140, 25, anchor="nw", image=logo2)
# Out:
# 4

# %%
base_frame = Frame(root, width= 800, height=500)
base_frame.place(x=240, y=60)

notebook = ttk.Notebook(base_frame)
notebook.pack()

frame1 = ttk.Frame(notebook, width=800, height=500)
frame1.pack()
frame1.pack_propagate(0)
notebook.add(frame1, text='Input')

frame2 = ttk.Frame(notebook, width=800, height=500)
frame2.pack()
frame2.pack_propagate(0)
notebook.add(frame2, text='Training')

frame3 = ttk.Frame(notebook, width=800, height=500)
frame3.pack()
frame3.pack_propagate(0)
notebook.add(frame3, text='Testing')

# %%
def OpenFile():
    global data_frame
    data_frame = askopenfilename(initialdir="G:/Semester 8/TA/DWT/Win32/Debug", title="Select A File", filetypes=(("csv files", "*.csv"),("all files", "*.*")))
    data_frame = pd.read_csv(data_frame, header=None)
    data_frame = data_frame.rename({250: 'Class'}, axis=1)
    var0.set("({} x {})".format(data_frame.shape[0],data_frame.shape[1]))

# %%
def SplitData():
    global X_train, Y_train, X_val, Y_val
    train_data, val_data = train_test_split(data_frame, test_size=0.15)
    
    X_train = train_data.loc[:, train_data.columns != 'Class']
    Y_train = train_data.loc[:, train_data.columns == 'Class']
    Y_train = to_categorical(Y_train)
    var1.set("X_train ({} x {})".format(X_train.shape[0],X_train.shape[1]))    
    var2.set("Y_train ({} x {})".format(Y_train.shape[0],Y_train.shape[1]))

    X_val = val_data.loc[:, val_data.columns != 'Class']
    Y_val = val_data.loc[:, val_data.columns == 'Class']
    Y_val = to_categorical(Y_val)
    var3.set("X_Val ({} x {})".format(X_val.shape[0],X_val.shape[1]))
    var4.set("Y_Val ({} x {})".format(Y_val.shape[0],Y_val.shape[1]))

    train_size = train_data['Class'].value_counts()
    fig1 = Figure(figsize=(5,5)) # create a figure object
    ax1 = fig1.add_subplot() # add an Axes to the figure
    ax1.pie(train_size, labels=['Normal','Ischemia'], colors=['blue','skyblue'],autopct='%1.1f%%',radius=1.2,textprops={'fontsize': 10})     
    pie1 = FigureCanvasTkAgg(fig1, in_frame2)
    pie1.get_tk_widget().pack(side=LEFT, fill=BOTH, expand=1)

    val_size = val_data['Class'].value_counts()
    fig2 = Figure(figsize=(5,5))
    ax2 = fig2.add_subplot() # add an Axes to the figure
    ax2.pie(val_size, labels=['Normal','Ischemia'], colors=['red','orange'],autopct='%1.1f%%',radius=1.2,textprops={'fontsize': 10})     
    pie2 = FigureCanvasTkAgg(fig2, in_frame2)
    pie2.get_tk_widget().pack(side=LEFT, fill=BOTH, expand=1)

    Label7 = Label(in_frame3, text=" Data Size Training ", bg="white")
    Label7.pack(side=LEFT, ipadx=147)
    Label8 = Label(in_frame3, text=" Data Size Validation ", bg="white")
    Label8.pack(side=LEFT, ipadx=147)

# %%
def Training():
    global ann_model
    ann_model = Sequential()
    ann_model.add(Dense(32, activation='relu', input_shape=(250,)))
    ann_model.add(Dense(24, activation='relu'))
    ann_model.add(Dense(2, activation='softmax'))
    ann_model.summary()    
    
    ann_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    #my_callbacks = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
    
    epocs = 300   
    class myCallback(tf.keras.callbacks.Callback):
        def on_epoch_begin(self, epoch, logs={}):
            speed = 1
            pbar['value'] += (speed/epocs)*100                
            percentLabel.config(text=str(math.ceil(pbar['value'])) + "%")                                                  
            in_frame1_21.update_idletasks()            
    my_callbacks = myCallback()

    history = ann_model.fit(
        X_train,Y_train,
        validation_data=(X_val, Y_val),
        batch_size=32,
        epochs=epocs,
        callbacks=[my_callbacks]
    )   

    taskLabel.config(text="Completed !")

    my_acc = history.history['accuracy']
    my_val_acc = history.history['val_accuracy']

    # plot accuracy
    fig3 = Figure(figsize=(5, 5))
    ax3 = fig3.add_subplot()    
    ax3.set_title('Training Accuracy')    
    ax3.set_ylabel('Accuracy')
    ax3.set_xlabel('Epochs')
    ax3.set_ylim([min(ax3.set_ylim()),1])
    ax3.plot(my_acc, label='Training')
    ax3.plot(my_val_acc, label='Validation')  
    ax3.legend(loc='lower right') 
    line1 = FigureCanvasTkAgg(fig3, in_frame1_23)
    line1.get_tk_widget().pack(side=LEFT, fill=BOTH, expand=1)    

    # visualize the loss training history
    my_loss = history.history['loss']
    my_val_loss = history.history['val_loss']

    # plot loss
    fig4 = Figure(figsize=(5, 5))
    ax4 = fig4.add_subplot()
    ax4.set_title('Training Loss')
    ax4.set_ylabel('Loss')
    ax4.set_xlabel('Epochs')    
    ax4.set_ylim([min(ax4.set_ylim()),1])
    ax4.plot(my_loss, label='Training')
    ax4.plot(my_val_loss, label='Validation')
    ax4.legend(loc='lower left')
    line2 = FigureCanvasTkAgg(fig4, in_frame1_23)
    line2.get_tk_widget().pack(side=LEFT, fill=BOTH, expand=1)

# %%
def OpenDataTest():
     global test_data
     test_data = askopenfilename(initialdir="G:/Semester 8/TA/DWT/Win32/Debug", title="Select A File", filetypes=(("csv files", "*.csv"),("all files", "*.*")))
     test_data = pd.read_csv(test_data, header=None)
     test_data = test_data.rename({250: 'Class'}, axis=1)
     var5.set("({} x {})".format(test_data.shape[0],test_data.shape[1]))

# %%
def SplitDataTest():
    global X_test, Y_test
    X_test = test_data.loc[:, test_data.columns != 'Class']
    Y_test = test_data.loc[:, test_data.columns == 'Class']
    Y_test = to_categorical(Y_test)
    var6.set("X_test ({} x {})".format(X_test.shape[0],X_test.shape[1]))
    var7.set("Y_test ({} x {})".format(Y_test.shape[0],Y_test.shape[1]))

    test_size = test_data['Class'].value_counts()
    fig5 = Figure(figsize=(5,5))
    ax5 = fig5.add_subplot() # add an Axes to the figure
    ax5.pie(test_size, labels=['Normal','Ischemia'], colors=['green','lightgreen'],autopct='%1.1f%%',radius=1.2,textprops={'fontsize': 10})     
    pie3 = FigureCanvasTkAgg(fig5, in_frame2_3_1)
    pie3.get_tk_widget().pack(side=TOP, expand=1)

    Label8 = Label(in_frame2_3_1, text=" Data Size Testing ", bg="white")
    Label8.pack(side=TOP, ipadx=147)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    print(' ')

    fig6 = Figure(figsize=(5,5))
    ax6 = fig6.add_subplot()
    ax6.imshow(cm, interpolation='nearest', cmap=cmap)
    ax6.set_title(title)
    #ax6.colorbar()
    tick_marks = np.arange(len(classes))
    #ax6.set_xticklabels(tick_marks, classes)
    #ax6.set_yticklabels(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        ax6.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    ax6.set_ylabel('True label')
    ax6.set_xlabel('Classified label')
    #ax6.tight_layout()
    confusion_chart = FigureCanvasTkAgg(fig6, in_frame2_3_2)
    confusion_chart.get_tk_widget().pack(side=TOP, padx=5, expand=1)

# %%
def TestingModel():
    hasil_evaluasi = ann_model.evaluate(X_test, Y_test, batch_size=32)
    var8.set("Accuracy : {:.2f}%".format(hasil_evaluasi[1] * 100))
    var9.set("Loss : {:.2f}%".format(hasil_evaluasi[0] * 100))

    Y_pred = ann_model.predict(X_test)
    Y_pred = np.argmax(Y_pred,axis=1)
    Y_true = np.argmax(Y_test,axis=1)
    cm = confusion_matrix(Y_true,Y_pred)
    plot_confusion_matrix(cm, classes=['Normal', 'Ischemia'])  
    print(type(classification_report(Y_true,Y_pred)))

# %%
#Frame1 "Input" Menu
in_frame1 = Frame(frame1, width=800, height=60, bg="white")
in_frame1.pack()
in_frame1.pack_propagate(0)

var0 = StringVar()
var1 = StringVar()
var2 = StringVar()
var3 = StringVar()
var4 = StringVar()

btn1 = Button(in_frame1, text="Load File", command=OpenFile)
btn1.pack(side=LEFT, ipadx=5, padx=20)
btn2 = Button(in_frame1, text="Split Data", command=SplitData)
btn2.pack(side=LEFT, ipadx=5, padx=20)

box0  = LabelFrame(in_frame1, text="Dataset Frame", bg="white")
box0.pack(side=LEFT, padx=5)
Label0 = Label(box0, text="", textvariable=var0, bg="white")
Label0.pack(side=TOP)

box1  = LabelFrame(in_frame1, text="Training Data Frame", bg="white")
box1.pack(side=LEFT, padx=5)
Label1 = Label(box1, text="", textvariable=var1, bg="white")
Label1.pack(side=TOP)
Label2 = Label(box1, text="", textvariable=var2, bg="white")
Label2.pack(side=TOP)

box2  = LabelFrame(in_frame1, text="Validation Data Frame", bg="white")
box2.pack(side=LEFT, padx=5)
Label3 = Label(box2, text="", textvariable=var3, bg="white")
Label3.pack(side=TOP)
Label4 = Label(box2, text="", textvariable=var4, bg="white")
Label4.pack(side=TOP)

in_frame2 = Frame(frame1, width=800, height=400, bg="white")
in_frame2.pack(side=TOP)
in_frame2.pack_propagate(0)

in_frame3 = Frame(frame1, width=800, height=40, bg="white")
in_frame3.pack(side=TOP)
in_frame3.pack_propagate(0)

# %%
#FRAME 2 "Training" Menu

in_frame1_2 = Frame(frame2, width=800, height=40, bg="white")
in_frame1_2.pack()
in_frame1_2.pack_propagate(0)

btn3 = Button(in_frame1_2, text="Training Model", command=Training)
btn3.pack(side=LEFT, padx=15)

in_frame1_21 = Frame(in_frame1_2, width=700, height=40, bg="white")
in_frame1_21.pack(side=RIGHT)
in_frame1_21.pack_propagate(0)

pbar = ttk.Progressbar(in_frame1_21,orient = HORIZONTAL,length = 700, mode = 'determinate')
pbar.pack(side=LEFT)

in_frame1_22 = Frame(frame2, width=800, height=20, bg="white")
in_frame1_22.pack()
in_frame1_22.pack_propagate(0)

in_frame1_22_1 = Frame(in_frame1_22, width=400, height=20, bg="white")
in_frame1_22_1.pack(side=LEFT)
in_frame1_22_1.pack_propagate(0)

in_frame1_22_2 = Frame(in_frame1_22, width=400, height=20, bg="white")
in_frame1_22_2.pack(side=LEFT)
in_frame1_22_2.pack_propagate(0)

percentLabel = Label(in_frame1_22_1, bg="white")
percentLabel.pack(side=RIGHT)

taskLabel = Label(in_frame1_22_2, bg="white")
taskLabel.pack(side=LEFT)

in_frame1_23 = Frame(frame2, width=800, height=440, bg="white")
in_frame1_23.pack()
in_frame1_23.pack_propagate(0)

# %%
#Frame 3 "Testing" Menu

in_frame1_3 = Frame(frame3, width=800, height=60, bg="white")
in_frame1_3.pack()
in_frame1_3.pack_propagate(0)

btn4 = Button(in_frame1_3, text="Load Data Test", command=OpenDataTest)
btn4.pack(side=LEFT, ipadx=5, padx=20)
btn5 = Button(in_frame1_3, text="Split Data", command=SplitDataTest)
btn5.pack(side=LEFT, ipadx=5, padx=20)
btn6 = Button(in_frame1_3, text="Testing", command=TestingModel)
btn6.pack(side=LEFT, ipadx=5, padx=20)

var5 = StringVar()
var6 = StringVar()
var7 = StringVar()
var8 = StringVar()
var9 = StringVar()

box3  = LabelFrame(in_frame1_3, text="Data Test Frame", bg="white")
box3.pack(side=LEFT, padx=10)
Label5 = Label(box3, text="", textvariable=var5, bg="white")
Label5.pack(side=TOP)

box4  = LabelFrame(in_frame1_3, text="Testing Data Frame", bg="white")
box4.pack(side=LEFT, padx=10)
Label6 = Label(box4, textvariable=var6, bg="white")
Label6.pack(side=TOP)
Label7 = Label(box4, textvariable=var7, bg="white")
Label7.pack(side=TOP)

box5  = LabelFrame(in_frame1_3, text="Testing Result", bg="white")
box5.pack(side=LEFT, padx=10)
Label9 = Label(box5, textvariable=var8, bg="white")
Label9.pack(side=TOP)
Label10 = Label(box5, textvariable=var9, bg="white")
Label10.pack(side=TOP)

in_frame2_3 = Frame(frame3, width=800, height=440)
in_frame2_3.pack()
in_frame2_3.pack_propagate(0)

in_frame2_3_1 = Frame(in_frame2_3, width=400, height=440, bg="white")
in_frame2_3_1.pack(side=LEFT)
in_frame2_3_1.pack_propagate(0)

in_frame2_3_2 = Frame(in_frame2_3, width=400, height=440, bg="white")
in_frame2_3_2.pack(side=LEFT)
in_frame2_3_2.pack_propagate(0)

# %%
root.mainloop()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                8032
#
#  dense_1 (Dense)             (None, 24)                792
#
#  dense_2 (Dense)             (None, 2)                 50
#
# =================================================================
# Total params: 8,874
# Trainable params: 8,874
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 83/83 [==============================] - 3s 10ms/step - loss: 0.7390 - accuracy: 0.4885 - val_loss: 0.7289 - val_accuracy: 0.4989
# Epoch 2/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.7289 - accuracy: 0.4964 - val_loss: 0.7193 - val_accuracy: 0.5032
# Epoch 3/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.7200 - accuracy: 0.5062 - val_loss: 0.7106 - val_accuracy: 0.5139
# Epoch 4/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.7122 - accuracy: 0.5202 - val_loss: 0.7036 - val_accuracy: 0.5332
# Epoch 5/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.7052 - accuracy: 0.5369 - val_loss: 0.6977 - val_accuracy: 0.5503
# Epoch 6/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6990 - accuracy: 0.5501 - val_loss: 0.6922 - val_accuracy: 0.5739
# Epoch 7/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6934 - accuracy: 0.5607 - val_loss: 0.6877 - val_accuracy: 0.5717
# Epoch 8/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6884 - accuracy: 0.5686 - val_loss: 0.6840 - val_accuracy: 0.5739
# Epoch 9/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6839 - accuracy: 0.5698 - val_loss: 0.6802 - val_accuracy: 0.5696
# Epoch 10/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6799 - accuracy: 0.5698 - val_loss: 0.6771 - val_accuracy: 0.5696
# Epoch 11/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6762 - accuracy: 0.5648 - val_loss: 0.6742 - val_accuracy: 0.5696
# Epoch 12/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6727 - accuracy: 0.5679 - val_loss: 0.6715 - val_accuracy: 0.5717
# Epoch 13/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.6694 - accuracy: 0.5709 - val_loss: 0.6689 - val_accuracy: 0.5739
# Epoch 14/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6664 - accuracy: 0.5732 - val_loss: 0.6665 - val_accuracy: 0.5696
# Epoch 15/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6634 - accuracy: 0.5777 - val_loss: 0.6643 - val_accuracy: 0.5717
# Epoch 16/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6605 - accuracy: 0.5796 - val_loss: 0.6622 - val_accuracy: 0.5782
# Epoch 17/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6579 - accuracy: 0.5807 - val_loss: 0.6600 - val_accuracy: 0.5782
# Epoch 18/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6552 - accuracy: 0.5849 - val_loss: 0.6581 - val_accuracy: 0.5782
# Epoch 19/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6527 - accuracy: 0.5860 - val_loss: 0.6560 - val_accuracy: 0.5782
# Epoch 20/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6501 - accuracy: 0.5898 - val_loss: 0.6542 - val_accuracy: 0.5846
# Epoch 21/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6477 - accuracy: 0.5947 - val_loss: 0.6524 - val_accuracy: 0.5867
# Epoch 22/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.6453 - accuracy: 0.5985 - val_loss: 0.6505 - val_accuracy: 0.5910
# Epoch 23/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6430 - accuracy: 0.6030 - val_loss: 0.6489 - val_accuracy: 0.5910
# Epoch 24/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6407 - accuracy: 0.6042 - val_loss: 0.6472 - val_accuracy: 0.5931
# Epoch 25/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.
300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5800 - accuracy: 0.6628 - val_loss: 0.5913 - val_accuracy: 0.6574
# Epoch 57/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5782 - accuracy: 0.6650 - val_loss: 0.5894 - val_accuracy: 0.6617
# Epoch 58/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5764 - accuracy: 0.6684 - val_loss: 0.5874 - val_accuracy: 0.6660
# Epoch 59/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5746 - accuracy: 0.6703 - val_loss: 0.5854 - val_accuracy: 0.6681
# Epoch 60/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5727 - accuracy: 0.6726 - val_loss: 0.5836 - val_accuracy: 0.6681
# Epoch 61/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5709 - accuracy: 0.6726 - val_loss: 0.5816 - val_accuracy: 0.6724
# Epoch 62/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5690 - accuracy: 0.6779 - val_loss: 0.5796 - val_accuracy: 0.6745
# Epoch 63/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5671 - accuracy: 0.6798 - val_loss: 0.5776 - val_accuracy: 0.6767
# Epoch 64/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5652 - accuracy: 0.6786 - val_loss: 0.5754 - val_accuracy: 0.6767
# Epoch 65/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5633 - accuracy: 0.6851 - val_loss: 0.5734 - val_accuracy: 0.6831
# Epoch 66/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5615 - accuracy: 0.6862 - val_loss: 0.5714 - val_accuracy: 0.6831
# Epoch 67/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5594 - accuracy: 0.6896 - val_loss: 0.5695 - val_accuracy: 0.6852
# Epoch 68/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5575 - accuracy: 0.6945 - val_loss: 0.5673 - val_accuracy: 0.6874
# Epoch 69/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5555 - accuracy: 0.6979 - val_loss: 0.5654 - val_accuracy: 0.6895
# Epoch 70/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5535 - accuracy: 0.6994 - val_loss: 0.5633 - val_accuracy: 0.6874
# Epoch 71/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5515 - accuracy: 0.7028 - val_loss: 0.5613 - val_accuracy: 0.6874
# Epoch 72/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5495 - accuracy: 0.7036 - val_loss: 0.5591 - val_accuracy: 0.6895
# Epoch 73/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5474 - accuracy: 0.7081 - val_loss: 0.5571 - val_accuracy: 0.6938
# Epoch 74/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5453 - accuracy: 0.7085 - val_loss: 0.5549 - val_accuracy: 0.6981
# Epoch 75/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.5433 - accuracy: 0.7108 - val_loss: 0.5530 - val_accuracy: 0.7002
# Epoch 76/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.5412 - accuracy: 0.7176 - val_loss: 0.5507 - val_accuracy: 0.7109
# Epoch 77/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.5392 - accuracy: 0.7206 - val_loss: 0.5485 - val_accuracy: 0.7131
# Epoch 78/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.5371 - accuracy: 0.7248 - val_loss: 0.5464 - val_accuracy: 0.7131
# Epoch 79/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5350 - accuracy: 0.7236 - val_loss: 0.5443 - val_accuracy: 0.7195
# Epoch 80/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5329 - accuracy: 0.7270 - val_loss: 0.5422 - val_accuracy: 0.7195
# Epoch 81/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5308 - accuracy: 0.7369 - val_loss: 0.5400 - val_accuracy: 0.7195
# Epoch 82/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.5287 - accuracy: 0.7395 - val_loss: 0.5378 - val_accuracy: 0.7238
# Epoch 83/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.5265 - accuracy: 0.7422 - val_loss: 0.5357 - val_accuracy: 0.7281
# Epoch 84/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.5244 - accuracy: 0.7433 - val_loss: 0.5335 - val_accuracy: 0.7323
# Epoch 85/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.5222 - accuracy: 0.7486 - val_loss: 0.5312 - val_accuracy: 0.7388
# Epoch 86/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.5200 - accuracy: 0.7516 - val_loss: 0.5289 - val_accuracy: 0.7473
# Epoch 87/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.
300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3737 - accuracy: 0.9134 - val_loss: 0.3863 - val_accuracy: 0.9122
# Epoch 150/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3715 - accuracy: 0.9157 - val_loss: 0.3841 - val_accuracy: 0.9143
# Epoch 151/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3693 - accuracy: 0.9168 - val_loss: 0.3819 - val_accuracy: 0.9122
# Epoch 152/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3671 - accuracy: 0.9176 - val_loss: 0.3799 - val_accuracy: 0.9143
# Epoch 153/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3649 - accuracy: 0.9195 - val_loss: 0.3779 - val_accuracy: 0.9122
# Epoch 154/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3627 - accuracy: 0.9202 - val_loss: 0.3759 - val_accuracy: 0.9143
# Epoch 155/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3606 - accuracy: 0.9221 - val_loss: 0.3737 - val_accuracy: 0.9122
# Epoch 156/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3584 - accuracy: 0.9217 - val_loss: 0.3718 - val_accuracy: 0.9122
# Epoch 157/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3563 - accuracy: 0.9217 - val_loss: 0.3699 - val_accuracy: 0.9143
# Epoch 158/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3542 - accuracy: 0.9225 - val_loss: 0.3679 - val_accuracy: 0.9122
# Epoch 159/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3521 - accuracy: 0.9229 - val_loss: 0.3659 - val_accuracy: 0.9122
# Epoch 160/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3500 - accuracy: 0.9236 - val_loss: 0.3640 - val_accuracy: 0.9101
# Epoch 161/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3479 - accuracy: 0.9248 - val_loss: 0.3620 - val_accuracy: 0.9101
# Epoch 162/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3457 - accuracy: 0.9259 - val_loss: 0.3601 - val_accuracy: 0.9122
# Epoch 163/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3437 - accuracy: 0.9263 - val_loss: 0.3580 - val_accuracy: 0.9122
# Epoch 164/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3416 - accuracy: 0.9267 - val_loss: 0.3561 - val_accuracy: 0.9122
# Epoch 165/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3396 - accuracy: 0.9267 - val_loss: 0.3542 - val_accuracy: 0.9165
# Epoch 166/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3375 - accuracy: 0.9270 - val_loss: 0.3523 - val_accuracy: 0.9186
# Epoch 167/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3355 - accuracy: 0.9282 - val_loss: 0.3505 - val_accuracy: 0.9186
# Epoch 168/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3335 - accuracy: 0.9301 - val_loss: 0.3487 - val_accuracy: 0.9186
# Epoch 169/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3316 - accuracy: 0.9319 - val_loss: 0.3466 - val_accuracy: 0.9208
# Epoch 170/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3296 - accuracy: 0.9319 - val_loss: 0.3448 - val_accuracy: 0.9186
# Epoch 171/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3277 - accuracy: 0.9327 - val_loss: 0.3430 - val_accuracy: 0.9229
# Epoch 172/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3257 - accuracy: 0.9331 - val_loss: 0.3412 - val_accuracy: 0.9229
# Epoch 173/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3238 - accuracy: 0.9335 - val_loss: 0.3393 - val_accuracy: 0.9229
# Epoch 174/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3219 - accuracy: 0.9342 - val_loss: 0.3376 - val_accuracy: 0.9229
# Epoch 175/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3200 - accuracy: 0.9338 - val_loss: 0.3358 - val_accuracy: 0.9272
# Epoch 176/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3182 - accuracy: 0.9346 - val_loss: 0.3340 - val_accuracy: 0.9293
# Epoch 177/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3163 - accuracy: 0.9346 - val_loss: 0.3321 - val_accuracy: 0.9293
# Epoch 178/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.3145 - accuracy: 0.9346 - val_loss: 0.3305 - val_accuracy: 0.9293
# Epoch 179/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3126 - accuracy: 0.9353 - val_loss: 0.3286 - val_accuracy: 0.9315
# Epoch 180/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3109 - accuracy: 0.9369 - val_loss: 0.3269 - val_accuracy: 0.9336
# Epoch 181/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3091 - accuracy: 0.9369 - val_loss: 0.3254 - val_accuracy: 0.9336
# Epoch 182/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3073 - accuracy: 0.9372 - val_loss: 0.3236 - val_accuracy: 0.9379
# Epoch 183/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3055 - accuracy: 0.9380 - val_loss: 0.3218 - val_accuracy: 0.9379
# Epoch 184/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3038 - accuracy: 0.9376 - val_loss: 0.3202 - val_accuracy: 0.9379
# Epoch 185/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3020 - accuracy: 0.9395 - val_loss: 0.3186 - val_accuracy: 0.9379
# Epoch 186/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3004 - accuracy: 0.9388 - val_loss: 0.3168 - val_accuracy: 0.9379
# Epoch 187/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2986 - accuracy: 0.9391 - val_loss: 0.3153 - val_accuracy: 0.9379
# Epoch 188/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2969 - accuracy: 0.9399 - val_loss: 0.3135 - val_accuracy: 0.9400
# Epoch 189/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2952 - accuracy: 0.9399 - val_loss: 0.3121 - val_accuracy: 0.9400
# Epoch 190/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2936 - accuracy: 0.9410 - val_loss: 0.3104 - val_accuracy: 0.9400
# Epoch 191/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2919 - accuracy: 0.9414 - val_loss: 0.3089 - val_accuracy: 0.9400
# Epoch 192/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2903 - accuracy: 0.9418 - val_loss: 0.3072 - val_accuracy: 0.9422
# Epoch 193/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2886 - accuracy: 0.9422 - val_loss: 0.3056 - val_accuracy: 0.9422
# Epoch 194/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2870 - accuracy: 0.9429 - val_loss: 0.3042 - val_accuracy: 0.9422
# Epoch 195/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2854 - accuracy: 0.9425 - val_loss: 0.3025 - val_accuracy: 0.9422
# Epoch 196/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.2839 - accuracy: 0.9429 - val_loss: 0.3009 - val_accuracy: 0.9422
# Epoch 197/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2823 - accuracy: 0.9429 - val_loss: 0.2996 - val_accuracy: 0.9422
# Epoch 198/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2807 - accuracy: 0.9433 - val_loss: 0.2980 - val_accuracy: 0.9422
# Epoch 199/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2792 - accuracy: 0.9433 - val_loss: 0.2964 - val_accuracy: 0.9422
# Epoch 200/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2776 - accuracy: 0.9456 - val_loss: 0.2949 - val_accuracy: 0.9422
# Epoch 201/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2760 - accuracy: 0.9452 - val_loss: 0.2934 - val_accuracy: 0.9443
# Epoch 202/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2745 - accuracy: 0.9459 - val_loss: 0.2921 - val_accuracy: 0.9465
# Epoch 203/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2731 - accuracy: 0.9463 - val_loss: 0.2907 - val_accuracy: 0.9465
# Epoch 204/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.2715 - accuracy: 0.9471 - val_loss: 0.2891 - val_accuracy: 0.9465
# Epoch 205/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2700 - accuracy: 0.9474 - val_loss: 0.2876 - val_accuracy: 0.9465
# Epoch 206/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2686 - accuracy: 0.9471 - val_loss: 0.2862 - val_accuracy: 0.9465
# Epoch 207/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2671 - accuracy: 0.9474 - val_loss: 0.2848 - val_accuracy: 0.9507
# Epoch 208/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2656 - accuracy: 0.9486 - val_loss: 0.2835 - val_accuracy: 0.9507
# Epoch 209/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2641 - accuracy: 0.9490 - val_loss: 0.2821 - val_accuracy: 0.9507
# Epoch 210/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.
300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2238 - accuracy: 0.9535 - val_loss: 0.2437 - val_accuracy: 0.9529
# Epoch 242/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2227 - accuracy: 0.9539 - val_loss: 0.2427 - val_accuracy: 0.9529
# Epoch 243/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2216 - accuracy: 0.9535 - val_loss: 0.2416 - val_accuracy: 0.9529
# Epoch 244/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2206 - accuracy: 0.9539 - val_loss: 0.2405 - val_accuracy: 0.9529
# Epoch 245/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2195 - accuracy: 0.9539 - val_loss: 0.2396 - val_accuracy: 0.9529
# Epoch 246/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2185 - accuracy: 0.9539 - val_loss: 0.2385 - val_accuracy: 0.9529
# Epoch 247/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2174 - accuracy: 0.9539 - val_loss: 0.2374 - val_accuracy: 0.9550
# Epoch 248/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2164 - accuracy: 0.9539 - val_loss: 0.2366 - val_accuracy: 0.9529
# Epoch 249/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2153 - accuracy: 0.9543 - val_loss: 0.2357 - val_accuracy: 0.9550
# Epoch 250/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2143 - accuracy: 0.9546 - val_loss: 0.2347 - val_accuracy: 0.9550
# Epoch 251/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2133 - accuracy: 0.9546 - val_loss: 0.2338 - val_accuracy: 0.9550
# Epoch 252/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2124 - accuracy: 0.9546 - val_loss: 0.2329 - val_accuracy: 0.9550
# Epoch 253/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2113 - accuracy: 0.9546 - val_loss: 0.2319 - val_accuracy: 0.9550
# Epoch 254/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2104 - accuracy: 0.9546 - val_loss: 0.2310 - val_accuracy: 0.9550
# Epoch 255/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2094 - accuracy: 0.9550 - val_loss: 0.2303 - val_accuracy: 0.9550
# Epoch 256/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2084 - accuracy: 0.9554 - val_loss: 0.2295 - val_accuracy: 0.9550
# Epoch 257/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2074 - accuracy: 0.9558 - val_loss: 0.2283 - val_accuracy: 0.9529
# Epoch 258/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2066 - accuracy: 0.9561 - val_loss: 0.2275 - val_accuracy: 0.9529
# Epoch 259/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.2056 - accuracy: 0.9565 - val_loss: 0.2267 - val_accuracy: 0.9529
# Epoch 260/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2047 - accuracy: 0.9565 - val_loss: 0.2258 - val_accuracy: 0.9529
# Epoch 261/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2038 - accuracy: 0.9565 - val_loss: 0.2250 - val_accuracy: 0.9529
# Epoch 262/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.2028 - accuracy: 0.9569 - val_loss: 0.2242 - val_accuracy: 0.9529
# Epoch 263/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2020 - accuracy: 0.9573 - val_loss: 0.2234 - val_accuracy: 0.9529
# Epoch 264/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2011 - accuracy: 0.9580 - val_loss: 0.2225 - val_accuracy: 0.9529
# Epoch 265/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.2002 - accuracy: 0.9573 - val_loss: 0.2218 - val_accuracy: 0.9529
# Epoch 266/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1994 - accuracy: 0.9580 - val_loss: 0.2210 - val_accuracy: 0.9507
# Epoch 267/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1985 - accuracy: 0.9588 - val_loss: 0.2203 - val_accuracy: 0.9507
# Epoch 268/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1976 - accuracy: 0.9584 - val_loss: 0.2194 - val_accuracy: 0.9529
# Epoch 269/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1968 - accuracy: 0.9588 - val_loss: 0.2187 - val_accuracy: 0.9507
# Epoch 270/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1959 - accuracy: 0.9588 - val_loss: 0.2179 - val_accuracy: 0.9507
# Epoch 271/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1951 - accuracy: 0.9592 - val_loss: 0.2171 - val_accuracy: 0.9507
# Epoch 272/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1942 - accuracy: 0.9592 - val_loss: 0.2165 - val_accuracy: 0.9507
# Epoch 273/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1934 - accuracy: 0.9599 - val_loss: 0.2158 - val_accuracy: 0.9507
# Epoch 274/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1927 - accuracy: 0.9595 - val_loss: 0.2152 - val_accuracy: 0.9507
# Epoch 275/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1918 - accuracy: 0.9595 - val_loss: 0.2146 - val_accuracy: 0.9507
# Epoch 276/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1910 - accuracy: 0.9599 - val_loss: 0.2137 - val_accuracy: 0.9507
# Epoch 277/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1902 - accuracy: 0.9607 - val_loss: 0.2129 - val_accuracy: 0.9507
# Epoch 278/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1895 - accuracy: 0.9607 - val_loss: 0.2123 - val_accuracy: 0.9507
# Epoch 279/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1887 - accuracy: 0.9603 - val_loss: 0.2117 - val_accuracy: 0.9507
# Epoch 280/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1879 - accuracy: 0.9611 - val_loss: 0.2109 - val_accuracy: 0.9507
# Epoch 281/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1871 - accuracy: 0.9611 - val_loss: 0.2104 - val_accuracy: 0.9507
# Epoch 282/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1863 - accuracy: 0.9611 - val_loss: 0.2096 - val_accuracy: 0.9507
# Epoch 283/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1856 - accuracy: 0.9607 - val_loss: 0.2090 - val_accuracy: 0.9507
# Epoch 284/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1849 - accuracy: 0.9614 - val_loss: 0.2082 - val_accuracy: 0.9507
# Epoch 285/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1841 - accuracy: 0.9611 - val_loss: 0.2077 - val_accuracy: 0.9507
# Epoch 286/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1834 - accuracy: 0.9626 - val_loss: 0.2070 - val_accuracy: 0.9507
# Epoch 287/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1826 - accuracy: 0.9611 - val_loss: 0.2064 - val_accuracy: 0.9507
# Epoch 288/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1819 - accuracy: 0.9611 - val_loss: 0.2058 - val_accuracy: 0.9507
# Epoch 289/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1812 - accuracy: 0.9607 - val_loss: 0.2053 - val_accuracy: 0.9507
# Epoch 290/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1805 - accuracy: 0.9603 - val_loss: 0.2046 - val_accuracy: 0.9507
# Epoch 291/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1798 - accuracy: 0.9603 - val_loss: 0.2039 - val_accuracy: 0.9507
# Epoch 292/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1791 - accuracy: 0.9622 - val_loss: 0.2035 - val_accuracy: 0.9507
# Epoch 293/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1784 - accuracy: 0.9614 - val_loss: 0.2028 - val_accuracy: 0.9507
# Epoch 294/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1777 - accuracy: 0.9618 - val_loss: 0.2024 - val_accuracy: 0.9507
# Epoch 295/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1770 - accuracy: 0.9614 - val_loss: 0.2018 - val_accuracy: 0.9507
# Epoch 296/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1764 - accuracy: 0.9618 - val_loss: 0.2011 - val_accuracy: 0.9507
# Epoch 297/300
# 83/83 [==============================] - 1s 10ms/step - loss: 0.1756 - accuracy: 0.9614 - val_loss: 0.2005 - val_accuracy: 0.9507
# Epoch 298/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1750 - accuracy: 0.9618 - val_loss: 0.1999 - val_accuracy: 0.9507
# Epoch 299/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1744 - accuracy: 0.9618 - val_loss: 0.1994 - val_accuracy: 0.9507
# Epoch 300/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.1736 - accuracy: 0.9626 - val_loss: 0.1987 - val_accuracy: 0.9507
# 18/18 [==============================] - 0s 7ms/step - loss: 0.1272 - accuracy: 0.9672
# Confusion matrix, without normalization
# [[204  13]
#  [  5 327]]
#
# <class 'str'>
