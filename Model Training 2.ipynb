# %%
import numpy as np
import pandas as pd
import itertools

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from keras.utils.np_utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import Sequential
from tensorflow import keras

import tensorflow as tf
import matplotlib.pyplot as plt

# %%
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    print(' ')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Classified label')
    plt.tight_layout()

# %% [markdown]
# DATA PREPARATION

# %%
normal_data= pd.read_csv('G:/Semester 8/TA/DWT/Win32/Debug/Decompose/normal_dataset.csv', header=None)
abnormal_data = pd.read_csv('G:/Semester 8/TA/DWT/Win32/Debug/Decompose/ischemia_dataset.csv', header=None)
data_frame = pd.concat([normal_data, abnormal_data], axis=0).sample(frac=1, random_state=15)
data_frame = data_frame.rename({250: 'Class'}, axis=1)
data_frame
# Out:
#            0      1       2        3        4       5       6       7       8  \
# 390  -0.2780 -0.349 -0.4160 -0.47800 -0.53100 -0.5740 -0.6080 -0.6300 -0.6390
# 401   0.1620  0.176  0.1910  0.20400  0.21700  0.2290  0.2390  0.2460  0.2520
# 986   0.8060  0.651  0.4870  0.31600  0.13900 -0.0423 -0.2250 -0.4060 -0.5830
# 1501 -0.6340 -0.525 -0.4210 -0.32300 -0.23300 -0.1510 -0.0777 -0.0126  0.0446
# 847   0.2870  0.323  0.3550  0.38200  0.40300  0.4160  0.4210  0.4160  0.4010
# ...      ...    ...     ...      ...      ...     ...     ...     ...     ...
# 505   0.3370  0.345  0.3450  0.33700  0.32100  0.2960  0.2620  0.2210  0.1710
# 1481 -0.4070 -0.358 -0.2970 -0.22300 -0.13700 -0.0410  0.0640  0.1760  0.2960
# 970   0.2810  0.236  0.1830  0.12300  0.05660 -0.0137 -0.0862 -0.1590 -0.2330
# 1198  1.5100  1.530  1.5400  1.54000  1.54000  1.5300  1.5000  1.4600  1.4100
# 1459  0.0272  0.020  0.0116  0.00332 -0.00386 -0.0105 -0.0153 -0.0180 -0.0195
#
#            9  ...     241     242     243      244      245     246     247  \
# 390  -0.6350  ...  0.2870  0.3180  0.3460  0.36800  0.38600  0.3980  0.4040
# 401   0.2560  ...  0.3080  0.2860  0.2640  0.24400  0.22600  0.2100  0.1960
# 986  -0.7550  ...  1.3800  1.3900  1.3900  1.40000  1.41000  1.4200  1.4400
# 1501  0.0943  ... -1.3000 -1.4400 -1.5700 -1.67000 -1.75000 -1.8100 -1.8400
# 847   0.3740  ...  0.1460  0.1750  0.2040  0.23500  0.26500  0.2960  0.3240
# ...      ...  ...     ...     ...     ...      ...      ...     ...     ...
# 505   0.1140  ...  0.0601  0.0666  0.0737  0.08130  0.08850  0.0957  0.1030
# 1481  0.4220  ... -0.4640 -0.5180 -0.5630 -0.59700 -0.62000 -0.6310 -0.6280
# 970  -0.3050  ...  0.0243  0.0341  0.0438  0.05270  0.06080  0.0687  0.0766
# 1198  1.3400  ... -0.8370 -0.5440 -0.2600  0.00867  0.25600  0.4810  0.6810
# 1459 -0.0192  ...  0.0466  0.0338  0.0206  0.00798 -0.00336 -0.0134 -0.0215
#
#          248     249  Class
# 390   0.4030  0.4030    0.0
# 401   0.1850  0.1850    0.0
# 986   1.4600  1.4600    1.0
# 1501 -1.8500 -1.8500    1.0
# 847   0.3500  0.3500    0.0
# ...      ...     ...    ...
# 505   0.1110  0.1110    1.0
# 1481 -0.6120 -0.6120    1.0
# 970   0.0848  0.0848    1.0
# 1198  0.8580  0.8580    1.0
# 1459 -0.0274 -0.0274    1.0
#
# [3112 rows x 251 columns]

# %%
train_data, val_data = train_test_split(data_frame, test_size=0.15)

X_train = train_data.loc[:, train_data.columns != 'Class']
Y_train = train_data.loc[:, train_data.columns == 'Class']
Y_train = to_categorical(Y_train)

X_val = val_data.loc[:, val_data.columns != 'Class']
Y_val = val_data.loc[:, val_data.columns == 'Class']
Y_val = to_categorical(Y_val)

print(X_train.shape)
print(Y_train.shape)

print(X_val.shape)
print(Y_val.shape)
# Out:
# (2645, 250)
# (2645, 2)
# (467, 250)
# (467, 2)

# %%
train_size = train_data['Class'].value_counts()
plt.pie(train_size, labels=['Normal','Ischemia'], colors=['blue','skyblue'],autopct='%1.1f%%',radius=1.5,textprops={'fontsize': 13})
p=plt.gcf()
plt.show()

# %%
val_size = val_data['Class'].value_counts()
plt.pie(val_size, labels=['Normal','Ischemia'], colors=['blue','skyblue'],autopct='%1.1f%%',radius=1.5,textprops={'fontsize': 13})
p=plt.gcf()
plt.show()

# %% [markdown]
# MODEL ARCHITECTURE

# %%
ann_model = Sequential()
ann_model.add(Dense(32, activation='relu', input_shape=(250,)))
ann_model.add(Dense(24, activation='relu'))
ann_model.add(Dense(2, activation='softmax'))
ann_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_27 (Dense)             (None, 32)                8032
# _________________________________________________________________
# dense_28 (Dense)             (None, 24)                792
# _________________________________________________________________
# dense_29 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 8,874
# Trainable params: 8,874
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# TRAINING SESSION

# %%
my_callbacks = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

ann_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = ann_model.fit(
    X_train,Y_train,
    validation_data=(X_val, Y_val),
    batch_size=32,
    epochs=300,
    callbacks=[my_callbacks]
)
# Out:
# Epoch 1/300
# 83/83 [==============================] - 1s 10ms/step - loss: 1.1520 - accuracy: 0.3955 - val_loss: 1.1318 - val_accuracy: 0.4111
# Epoch 2/300
# 83/83 [==============================] - 0s 5ms/step - loss: 1.0948 - accuracy: 0.4004 - val_loss: 1.0817 - val_accuracy: 0.4218
# Epoch 3/300
# 83/83 [==============================] - 0s 6ms/step - loss: 1.0431 - accuracy: 0.4083 - val_loss: 1.0370 - val_accuracy: 0.4283
# Epoch 4/300
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9968 - accuracy: 0.4231 - val_loss: 0.9966 - val_accuracy: 0.4411
# Epoch 5/300
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9555 - accuracy: 0.4401 - val_loss: 0.9600 - val_accuracy: 0.4454
# Epoch 6/300
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9184 - accuracy: 0.4495 - val_loss: 0.9271 - val_accuracy: 0.4518
# Epoch 7/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.8852 - accuracy: 0.4628 - val_loss: 0.8973 - val_accuracy: 0.4497
# Epoch 8/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.8553 - accuracy: 0.4741 - val_loss: 0.8710 - val_accuracy: 0.4582
# Epoch 9/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.8291 - accuracy: 0.4919 - val_loss: 0.8473 - val_accuracy: 0.4668
# Epoch 10/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.8058 - accuracy: 0.5036 - val_loss: 0.8268 - val_accuracy: 0.4732
# Epoch 11/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7854 - accuracy: 0.5134 - val_loss: 0.8080 - val_accuracy: 0.4904
# Epoch 12/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.7673 - accuracy: 0.5267 - val_loss: 0.7915 - val_accuracy: 0.5011
# Epoch 13/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.7513 - accuracy: 0.5338 - val_loss: 0.7769 - val_accuracy: 0.4968
# Epoch 14/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.7374 - accuracy: 0.5452 - val_loss: 0.7642 - val_accuracy: 0.5139
# Epoch 15/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.7251 - accuracy: 0.5505 - val_loss: 0.7527 - val_accuracy: 0.5225
# Epoch 16/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.7141 - accuracy: 0.5546 - val_loss: 0.7425 - val_accuracy: 0.5161
# Epoch 17/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.7043 - accuracy: 0.5626 - val_loss: 0.7334 - val_accuracy: 0.5246
# Epoch 18/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6954 - accuracy: 0.5728 - val_loss: 0.7252 - val_accuracy: 0.5310
# Epoch 19/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6874 - accuracy: 0.5769 - val_loss: 0.7175 - val_accuracy: 0.5375
# Epoch 20/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6801 - accuracy: 0.5856 - val_loss: 0.7103 - val_accuracy: 0.5418
# Epoch 21/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6733 - accuracy: 0.5921 - val_loss: 0.7038 - val_accuracy: 0.5418
# Epoch 22/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6671 - accuracy: 0.5943 - val_loss: 0.6975 - val_accuracy: 0.5439
# Epoch 23/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6612 - accuracy: 0.5928 - val_loss: 0.6916 - val_accuracy: 0.5375
# Epoch 24/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6558 - accuracy: 0.5928 - val_loss: 0.6861 - val_accuracy: 0.5439
# Epoch 25/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6505 - accuracy: 0.5936 - val_loss: 0.6811 - val_accuracy: 0.5460
# Epoch 26/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.6456 - accuracy: 0.5974 - val_loss: 0.6759 - val_accuracy: 0.5439
# Epoch 27/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6408 - accuracy: 0.6023 - val_loss: 0.6713 - val_accuracy: 0.5503
# Epoch 28/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6363 - accuracy: 0.6049 - val_loss: 0.6667 - val_accuracy: 0.5482
# Epoch 29/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6320 - accuracy: 0.6110 - val_loss: 0.6622 - val_accuracy: 0.5503
# Epoch 30/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6278 - accuracy: 0.6155 - val_loss: 0.6582 - val_accuracy: 0.5610
# Epoch 31/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6238 - accuracy: 0.6216 - val_loss: 0.6540 - val_accuracy: 0.5717
# Epoch 32/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6199 - accuracy: 0.6261 - val_loss: 0.6501 - val_accuracy: 0.5824
# Epoch 33/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.6161 - accuracy: 0.6310 - val_loss: 0.6463 - val_accuracy: 0.5910
# Epoch 34/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6123 - accuracy: 0.6340 - val_loss: 0.6427 - val_accuracy: 0.5974
# Epoch 35/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6087 - accuracy: 0.6340 - val_loss: 0.6390 - val_accuracy: 0.6103
# Epoch 36/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6053 - accuracy: 0.6367 - val_loss: 0.6356 - val_accuracy: 0.6124
# Epoch 37/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.6018 - accuracy: 0.6423 - val_loss: 0.6322 - val_accuracy: 0.6081
# Epoch 38/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5985 - accuracy: 0.6435 - val_loss: 0.6289 - val_accuracy: 0.6124
# Epoch 39/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5951 - accuracy: 0.6491 - val_loss: 0.6257 - val_accuracy: 0.6146
# Epoch 40/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5920 - accuracy: 0.6522 - val_loss: 0.6227 - val_accuracy: 0.6124
# Epoch 41/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5889 - accuracy: 0.6582 - val_loss: 0.6194 - val_accuracy: 0.6167
# Epoch 42/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5858 - accuracy: 0.6612 - val_loss: 0.6165 - val_accuracy: 0.6167
# Epoch 43/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5828 - accuracy: 0.6654 - val_loss: 0.6132 - val_accuracy: 0.6253
# Epoch 44/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5798 - accuracy: 0.6669 - val_loss: 0.6101 - val_accuracy: 0.6296
# Epoch 45/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5768 - accuracy: 0.6752 - val_loss: 0.6071 - val_accuracy: 0.6317
# Epoch 46/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5739 - accuracy: 0.6775 - val_loss: 0.6041 - val_accuracy: 0.6317
# Epoch 47/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5710 - accuracy: 0.6820 - val_loss: 0.6010 - val_accuracy: 0.6338
# Epoch 48/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5681 - accuracy: 0.6839 - val_loss: 0.5981 - val_accuracy: 0.6403
# Epoch 49/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5652 - accuracy: 0.6904 - val_loss: 0.5952 - val_accuracy: 0.6424
# Epoch 50/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5624 - accuracy: 0.6957 - val_loss: 0.5922 - val_accuracy: 0.6488
# Epoch 51/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5595 - accuracy: 0.7025 - val_loss: 0.5892 - val_accuracy: 0.6574
# Epoch 52/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5567 - accuracy: 0.7062 - val_loss: 0.5864 - val_accuracy: 0.6552
# Epoch 53/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5538 - accuracy: 0.7100 - val_loss: 0.5833 - val_accuracy: 0.6660
# Epoch 54/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5509 - accuracy: 0.7134 - val_loss: 0.5805 - val_accuracy: 0.6745
# Epoch 55/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5482 - accuracy: 0.7172 - val_loss: 0.5779 - val_accuracy: 0.6788
# Epoch 56/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5455 - accuracy: 0.7229 - val_loss: 0.5752 - val_accuracy: 0.6809
# Epoch 57/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5429 - accuracy: 0.7248 - val_loss: 0.5728 - val_accuracy: 0.6831
# Epoch 58/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5403 - accuracy: 0.7308 - val_loss: 0.5703 - val_accuracy: 0.6852
# Epoch 59/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.5378 - accuracy: 0.7376 - val_loss: 0.5679 - val_accuracy: 0.6916
# Epoch 60/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.5353 - accuracy: 0.7414 - val_loss: 0.5655 - val_accuracy: 0.6959
# Epoch 61/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5328 - accuracy: 0.7456 - val_loss: 0.5630 - val_accuracy: 0.6981
# Epoch 62/300
# 83/83 [==============================] - 0s 5ms/step - loss: 0.5303 - accuracy: 0.7478 - val_loss: 0.5606 - val_accuracy: 0.7002
# Epoch 63/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5280 - accuracy: 0.7535 - val_loss: 0.5582 - val_accuracy: 0.7024
# Epoch 64/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5255 - accuracy: 0.7561 - val_loss: 0.5559 - val_accuracy: 0.7066
# Epoch 65/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5232 - accuracy: 0.7599 - val_loss: 0.5536 - val_accuracy: 0.7066
# Epoch 66/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5208 - accuracy: 0.7641 - val_loss: 0.5514 - val_accuracy: 0.7109
# Epoch 67/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.5186 - accuracy: 0.7686 - val_loss: 0.5492 - val_accuracy: 0.7173
# Epoch 68/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5163 - accuracy: 0.7720 - val_loss: 0.5469 - val_accuracy: 0.7216
# Epoch 69/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.5140 - accuracy: 0.7750 - val_loss: 0.5448 - val_accuracy: 0.7216
# Epoch 70/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5119 - accuracy: 0.7781 - val_loss: 0.5423 - val_accuracy: 0.7195
# Epoch 71/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5096 - accuracy: 0.7815 - val_loss: 0.5402 - val_accuracy: 0.7259
# Epoch 72/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.5074 - accuracy: 0.7853 - val_loss: 0.5379 - val_accuracy: 0.7345
# Epoch 73/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5052 - accuracy: 0.7871 - val_loss: 0.5356 - val_accuracy: 0.7388
# Epoch 74/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.5030 - accuracy: 0.7905 - val_loss: 0.5334 - val_accuracy: 0.7473
# Epoch 75/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5008 - accuracy: 0.7917 - val_loss: 0.5312 - val_accuracy: 0.7516
# Epoch 76/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4986 - accuracy: 0.7966 - val_loss: 0.5289 - val_accuracy: 0.7537
# Epoch 77/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4965 - accuracy: 0.8004 - val_loss: 0.5268 - val_accuracy: 0.7559
# Epoch 78/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4943 - accuracy: 0.8030 - val_loss: 0.5247 - val_accuracy: 0.7559
# Epoch 79/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4921 - accuracy: 0.8068 - val_loss: 0.5224 - val_accuracy: 0.7623
# Epoch 80/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4899 - accuracy: 0.8091 - val_loss: 0.5203 - val_accuracy: 0.7645
# Epoch 81/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4878 - accuracy: 0.8095 - val_loss: 0.5182 - val_accuracy: 0.7687
# Epoch 82/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4856 - accuracy: 0.8136 - val_loss: 0.5160 - val_accuracy: 0.7730
# Epoch 83/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4834 - accuracy: 0.8155 - val_loss: 0.5138 - val_accuracy: 0.7752
# Epoch 84/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4812 - accuracy: 0.8178 - val_loss: 0.5116 - val_accuracy: 0.7773
# Epoch 85/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4790 - accuracy: 0.8216 - val_loss: 0.5094 - val_accuracy: 0.7794
# Epoch 86/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4767 - accuracy: 0.8242 - val_loss: 0.5071 - val_accuracy: 0.7837
# Epoch 87/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4745 - accuracy: 0.8253 - val_loss: 0.5050 - val_accuracy: 0.7859
# Epoch 88/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4722 - accuracy: 0.8272 - val_loss: 0.5026 - val_accuracy: 0.7859
# Epoch 89/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4700 - accuracy: 0.8302 - val_loss: 0.5004 - val_accuracy: 0.7859
# Epoch 90/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4677 - accuracy: 0.8325 - val_loss: 0.4981 - val_accuracy: 0.7901
# Epoch 91/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4654 - accuracy: 0.8355 - val_loss: 0.4960 - val_accuracy: 0.7901
# Epoch 92/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4631 - accuracy: 0.8363 - val_loss: 0.4936 - val_accuracy: 0.7923
# Epoch 93/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4608 - accuracy: 0.8378 - val_loss: 0.4913 - val_accuracy: 0.7944
# Epoch 94/300
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4585 - accuracy: 0.8412 - val_loss: 0.4891 - val_accuracy: 0.7987
# Epoch 95/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4562 - accuracy: 0.8408 - val_loss: 0.4870 - val_accuracy: 0.7966
# Epoch 96/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4539 - accuracy: 0.8427 - val_loss: 0.4848 - val_accuracy: 0.7987
# Epoch 97/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.4515 - accuracy: 0.8461 - val_loss: 0.4828 - val_accuracy: 0.8009
# Epoch 98/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4493 - accuracy: 0.8484 - val_loss: 0.4804 - val_accuracy: 0.8051
# Epoch 99/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4469 - accuracy: 0.8510 - val_loss: 0.4785 - val_accuracy: 0.8073
# Epoch 100/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4446 - accuracy: 0.8526 - val_loss: 0.4761 - val_accuracy: 0.8137
# Epoch 101/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4423 - accuracy: 0.8526 - val_loss: 0.4738 - val_accuracy: 0.8158
# Epoch 102/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4400 - accuracy: 0.8544 - val_loss: 0.4717 - val_accuracy: 0.8158
# Epoch 103/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4377 - accuracy: 0.8560 - val_loss: 0.4693 - val_accuracy: 0.8158
# Epoch 104/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4354 - accuracy: 0.8563 - val_loss: 0.4673 - val_accuracy: 0.8137
# Epoch 105/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4331 - accuracy: 0.8578 - val_loss: 0.4650 - val_accuracy: 0.8223
# Epoch 106/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4308 - accuracy: 0.8586 - val_loss: 0.4627 - val_accuracy: 0.8244
# Epoch 107/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4286 - accuracy: 0.8616 - val_loss: 0.4605 - val_accuracy: 0.8266
# Epoch 108/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4263 - accuracy: 0.8635 - val_loss: 0.4585 - val_accuracy: 0.8287
# Epoch 109/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4241 - accuracy: 0.8631 - val_loss: 0.4563 - val_accuracy: 0.8330
# Epoch 110/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4219 - accuracy: 0.8665 - val_loss: 0.4542 - val_accuracy: 0.8330
# Epoch 111/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4197 - accuracy: 0.8699 - val_loss: 0.4520 - val_accuracy: 0.8373
# Epoch 112/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4176 - accuracy: 0.8722 - val_loss: 0.4499 - val_accuracy: 0.8394
# Epoch 113/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4155 - accuracy: 0.8760 - val_loss: 0.4477 - val_accuracy: 0.8394
# Epoch 114/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.4133 - accuracy: 0.8767 - val_loss: 0.4455 - val_accuracy: 0.8415
# Epoch 115/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4112 - accuracy: 0.8798 - val_loss: 0.4434 - val_accuracy: 0.8437
# Epoch 116/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4090 - accuracy: 0.8824 - val_loss: 0.4415 - val_accuracy: 0.8480
# Epoch 117/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4070 - accuracy: 0.8832 - val_loss: 0.4394 - val_accuracy: 0.8480
# Epoch 118/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4048 - accuracy: 0.8847 - val_loss: 0.4373 - val_accuracy: 0.8480
# Epoch 119/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.4028 - accuracy: 0.8862 - val_loss: 0.4354 - val_accuracy: 0.8522
# Epoch 120/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.4007 - accuracy: 0.8885 - val_loss: 0.4332 - val_accuracy: 0.8522
# Epoch 121/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.3986 - accuracy: 0.8911 - val_loss: 0.4311 - val_accuracy: 0.8565
# Epoch 122/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3966 - accuracy: 0.8926 - val_loss: 0.4293 - val_accuracy: 0.8544
# Epoch 123/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.3946 - accuracy: 0.8953 - val_loss: 0.4273 - val_accuracy: 0.8608
# Epoch 124/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3926 - accuracy: 0.8957 - val_loss: 0.4251 - val_accuracy: 0.8608
# Epoch 125/300
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3906 - accuracy: 0.8972 - val_loss: 0.4233 - val_accuracy: 0.8630
# Epoch 126/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3886 - accuracy: 0.8983 - val_loss: 0.4213 - val_accuracy: 0.8630
# Epoch 127/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3866 - accuracy: 0.8991 - val_loss: 0.4194 - val_accuracy: 0.8608
# Epoch 128/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3846 - accuracy: 0.9006 - val_loss: 0.4174 - val_accuracy: 0.8608
# Epoch 129/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3827 - accuracy: 0.9043 - val_loss: 0.4155 - val_accuracy: 0.8672
# Epoch 130/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3807 - accuracy: 0.9047 - val_loss: 0.4135 - val_accuracy: 0.8651
# Epoch 131/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.3788 - accuracy: 0.9043 - val_loss: 0.4117 - val_accuracy: 0.8651
# Epoch 132/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3768 - accuracy: 0.9078 - val_loss: 0.4096 - val_accuracy: 0.8651
# Epoch 133/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3749 - accuracy: 0.9093 - val_loss: 0.4077 - val_accuracy: 0.8672
# Epoch 134/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3730 - accuracy: 0.9119 - val_loss: 0.4058 - val_accuracy: 0.8694
# Epoch 135/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3711 - accuracy: 0.9115 - val_loss: 0.4040 - val_accuracy: 0.8694
# Epoch 136/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3692 - accuracy: 0.9130 - val_loss: 0.4021 - val_accuracy: 0.8737
# Epoch 137/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3673 - accuracy: 0.9142 - val_loss: 0.4002 - val_accuracy: 0.8758
# Epoch 138/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3655 - accuracy: 0.9157 - val_loss: 0.3984 - val_accuracy: 0.8779
# Epoch 139/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3636 - accuracy: 0.9164 - val_loss: 0.3966 - val_accuracy: 0.8779
# Epoch 140/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3618 - accuracy: 0.9176 - val_loss: 0.3948 - val_accuracy: 0.8801
# Epoch 141/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3599 - accuracy: 0.9187 - val_loss: 0.3930 - val_accuracy: 0.8844
# Epoch 142/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3581 - accuracy: 0.9191 - val_loss: 0.3912 - val_accuracy: 0.8865
# Epoch 143/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3563 - accuracy: 0.9202 - val_loss: 0.3895 - val_accuracy: 0.8865
# Epoch 144/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3544 - accuracy: 0.9210 - val_loss: 0.3876 - val_accuracy: 0.8865
# Epoch 145/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3526 - accuracy: 0.9217 - val_loss: 0.3858 - val_accuracy: 0.8865
# Epoch 146/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3509 - accuracy: 0.9236 - val_loss: 0.3840 - val_accuracy: 0.8908
# Epoch 147/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3490 - accuracy: 0.9236 - val_loss: 0.3824 - val_accuracy: 0.8908
# Epoch 148/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3471 - accuracy: 0.9248 - val_loss: 0.3805 - val_accuracy: 0.8908
# Epoch 149/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3454 - accuracy: 0.9263 - val_loss: 0.3788 - val_accuracy: 0.8908
# Epoch 150/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3435 - accuracy: 0.9274 - val_loss: 0.3770 - val_accuracy: 0.8908
# Epoch 151/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.3418 - accuracy: 0.9282 - val_loss: 0.3754 - val_accuracy: 0.8908
# Epoch 152/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.3399 - accuracy: 0.9304 - val_loss: 0.3737 - val_accuracy: 0.8929
# Epoch 153/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3382 - accuracy: 0.9308 - val_loss: 0.3721 - val_accuracy: 0.8972
# Epoch 154/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3364 - accuracy: 0.9312 - val_loss: 0.3703 - val_accuracy: 0.8994
# Epoch 155/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3346 - accuracy: 0.9312 - val_loss: 0.3687 - val_accuracy: 0.8994
# Epoch 156/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3328 - accuracy: 0.9323 - val_loss: 0.3671 - val_accuracy: 0.8994
# Epoch 157/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3311 - accuracy: 0.9316 - val_loss: 0.3654 - val_accuracy: 0.9015
# Epoch 158/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3293 - accuracy: 0.9323 - val_loss: 0.3638 - val_accuracy: 0.9015
# Epoch 159/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.3276 - accuracy: 0.9346 - val_loss: 0.3623 - val_accuracy: 0.9058
# Epoch 160/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3258 - accuracy: 0.9353 - val_loss: 0.3606 - val_accuracy: 0.9079
# Epoch 161/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3241 - accuracy: 0.9361 - val_loss: 0.3591 - val_accuracy: 0.9101
# Epoch 162/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.3224 - accuracy: 0.9372 - val_loss: 0.3576 - val_accuracy: 0.9101
# Epoch 163/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3206 - accuracy: 0.9365 - val_loss: 0.3560 - val_accuracy: 0.9101
# Epoch 164/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3189 - accuracy: 0.9372 - val_loss: 0.3543 - val_accuracy: 0.9143
# Epoch 165/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3173 - accuracy: 0.9372 - val_loss: 0.3528 - val_accuracy: 0.9122
# Epoch 166/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3155 - accuracy: 0.9372 - val_loss: 0.3513 - val_accuracy: 0.9143
# Epoch 167/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3138 - accuracy: 0.9376 - val_loss: 0.3498 - val_accuracy: 0.9143
# Epoch 168/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.3121 - accuracy: 0.9372 - val_loss: 0.3485 - val_accuracy: 0.9143
# Epoch 169/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3105 - accuracy: 0.9372 - val_loss: 0.3470 - val_accuracy: 0.9165
# Epoch 170/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3088 - accuracy: 0.9372 - val_loss: 0.3454 - val_accuracy: 0.9165
# Epoch 171/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3071 - accuracy: 0.9372 - val_loss: 0.3441 - val_accuracy: 0.9186
# Epoch 172/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3055 - accuracy: 0.9388 - val_loss: 0.3426 - val_accuracy: 0.9186
# Epoch 173/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3038 - accuracy: 0.9380 - val_loss: 0.3412 - val_accuracy: 0.9208
# Epoch 174/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3022 - accuracy: 0.9388 - val_loss: 0.3397 - val_accuracy: 0.9208
# Epoch 175/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.3006 - accuracy: 0.9391 - val_loss: 0.3383 - val_accuracy: 0.9208
# Epoch 176/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2990 - accuracy: 0.9391 - val_loss: 0.3367 - val_accuracy: 0.9208
# Epoch 177/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.2974 - accuracy: 0.9406 - val_loss: 0.3354 - val_accuracy: 0.9208
# Epoch 178/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2958 - accuracy: 0.9406 - val_loss: 0.3340 - val_accuracy: 0.9208
# Epoch 179/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.2942 - accuracy: 0.9414 - val_loss: 0.3326 - val_accuracy: 0.9208
# Epoch 180/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.2926 - accuracy: 0.9429 - val_loss: 0.3311 - val_accuracy: 0.9251
# Epoch 181/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.2910 - accuracy: 0.9437 - val_loss: 0.3298 - val_accuracy: 0.9229
# Epoch 182/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2894 - accuracy: 0.9444 - val_loss: 0.3283 - val_accuracy: 0.9272
# Epoch 183/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2879 - accuracy: 0.9456 - val_loss: 0.3271 - val_accuracy: 0.9251
# Epoch 184/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2863 - accuracy: 0.9444 - val_loss: 0.3257 - val_accuracy: 0.9293
# Epoch 185/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2848 - accuracy: 0.9467 - val_loss: 0.3243 - val_accuracy: 0.9293
# Epoch 186/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2832 - accuracy: 0.9463 - val_loss: 0.3231 - val_accuracy: 0.9293
# Epoch 187/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2817 - accuracy: 0.9467 - val_loss: 0.3216 - val_accuracy: 0.9315
# Epoch 188/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2801 - accuracy: 0.9474 - val_loss: 0.3205 - val_accuracy: 0.9315
# Epoch 189/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2786 - accuracy: 0.9471 - val_loss: 0.3192 - val_accuracy: 0.9315
# Epoch 190/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2770 - accuracy: 0.9482 - val_loss: 0.3177 - val_accuracy: 0.9336
# Epoch 191/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2755 - accuracy: 0.9490 - val_loss: 0.3164 - val_accuracy: 0.9336
# Epoch 192/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2740 - accuracy: 0.9493 - val_loss: 0.3151 - val_accuracy: 0.9336
# Epoch 193/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2725 - accuracy: 0.9493 - val_loss: 0.3139 - val_accuracy: 0.9358
# Epoch 194/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2710 - accuracy: 0.9505 - val_loss: 0.3126 - val_accuracy: 0.9358
# Epoch 195/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2695 - accuracy: 0.9501 - val_loss: 0.3114 - val_accuracy: 0.9358
# Epoch 196/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2680 - accuracy: 0.9512 - val_loss: 0.3102 - val_accuracy: 0.9336
# Epoch 197/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2666 - accuracy: 0.9516 - val_loss: 0.3088 - val_accuracy: 0.9336
# Epoch 198/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2652 - accuracy: 0.9520 - val_loss: 0.3075 - val_accuracy: 0.9336
# Epoch 199/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2637 - accuracy: 0.9527 - val_loss: 0.3064 - val_accuracy: 0.9336
# Epoch 200/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2623 - accuracy: 0.9527 - val_loss: 0.3053 - val_accuracy: 0.9358
# Epoch 201/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2609 - accuracy: 0.9535 - val_loss: 0.3040 - val_accuracy: 0.9358
# Epoch 202/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2595 - accuracy: 0.9539 - val_loss: 0.3028 - val_accuracy: 0.9358
# Epoch 203/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2581 - accuracy: 0.9543 - val_loss: 0.3018 - val_accuracy: 0.9358
# Epoch 204/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2567 - accuracy: 0.9543 - val_loss: 0.3006 - val_accuracy: 0.9358
# Epoch 205/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2554 - accuracy: 0.9543 - val_loss: 0.2994 - val_accuracy: 0.9358
# Epoch 206/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2540 - accuracy: 0.9535 - val_loss: 0.2984 - val_accuracy: 0.9379
# Epoch 207/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2527 - accuracy: 0.9539 - val_loss: 0.2972 - val_accuracy: 0.9379
# Epoch 208/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2514 - accuracy: 0.9546 - val_loss: 0.2962 - val_accuracy: 0.9379
# Epoch 209/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2500 - accuracy: 0.9546 - val_loss: 0.2951 - val_accuracy: 0.9379
# Epoch 210/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2487 - accuracy: 0.9546 - val_loss: 0.2940 - val_accuracy: 0.9379
# Epoch 211/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2474 - accuracy: 0.9554 - val_loss: 0.2930 - val_accuracy: 0.9379
# Epoch 212/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.2461 - accuracy: 0.9554 - val_loss: 0.2918 - val_accuracy: 0.9379
# Epoch 213/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2448 - accuracy: 0.9558 - val_loss: 0.2909 - val_accuracy: 0.9400
# Epoch 214/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.2436 - accuracy: 0.9565 - val_loss: 0.2899 - val_accuracy: 0.9400
# Epoch 215/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2423 - accuracy: 0.9561 - val_loss: 0.2887 - val_accuracy: 0.9400
# Epoch 216/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2410 - accuracy: 0.9569 - val_loss: 0.2878 - val_accuracy: 0.9400
# Epoch 217/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2399 - accuracy: 0.9573 - val_loss: 0.2868 - val_accuracy: 0.9379
# Epoch 218/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2387 - accuracy: 0.9580 - val_loss: 0.2859 - val_accuracy: 0.9379
# Epoch 219/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2374 - accuracy: 0.9584 - val_loss: 0.2849 - val_accuracy: 0.9379
# Epoch 220/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2362 - accuracy: 0.9588 - val_loss: 0.2839 - val_accuracy: 0.9379
# Epoch 221/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2350 - accuracy: 0.9599 - val_loss: 0.2830 - val_accuracy: 0.9379
# Epoch 222/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2338 - accuracy: 0.9595 - val_loss: 0.2819 - val_accuracy: 0.9379
# Epoch 223/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.2327 - accuracy: 0.9607 - val_loss: 0.2811 - val_accuracy: 0.9379
# Epoch 224/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2315 - accuracy: 0.9611 - val_loss: 0.2800 - val_accuracy: 0.9379
# Epoch 225/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2303 - accuracy: 0.9611 - val_loss: 0.2792 - val_accuracy: 0.9379
# Epoch 226/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2292 - accuracy: 0.9607 - val_loss: 0.2782 - val_accuracy: 0.9379
# Epoch 227/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2280 - accuracy: 0.9611 - val_loss: 0.2774 - val_accuracy: 0.9379
# Epoch 228/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2269 - accuracy: 0.9611 - val_loss: 0.2765 - val_accuracy: 0.9379
# Epoch 229/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2257 - accuracy: 0.9607 - val_loss: 0.2754 - val_accuracy: 0.9400
# Epoch 230/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2246 - accuracy: 0.9614 - val_loss: 0.2747 - val_accuracy: 0.9400
# Epoch 231/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.2234 - accuracy: 0.9614 - val_loss: 0.2737 - val_accuracy: 0.9400
# Epoch 232/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2224 - accuracy: 0.9618 - val_loss: 0.2728 - val_accuracy: 0.9400
# Epoch 233/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.2213 - accuracy: 0.9614 - val_loss: 0.2720 - val_accuracy: 0.9400
# Epoch 234/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2201 - accuracy: 0.9614 - val_loss: 0.2711 - val_accuracy: 0.9422
# Epoch 235/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2191 - accuracy: 0.9618 - val_loss: 0.2702 - val_accuracy: 0.9422
# Epoch 236/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2180 - accuracy: 0.9618 - val_loss: 0.2695 - val_accuracy: 0.9422
# Epoch 237/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2169 - accuracy: 0.9629 - val_loss: 0.2687 - val_accuracy: 0.9422
# Epoch 238/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2159 - accuracy: 0.9629 - val_loss: 0.2677 - val_accuracy: 0.9422
# Epoch 239/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2149 - accuracy: 0.9633 - val_loss: 0.2670 - val_accuracy: 0.9422
# Epoch 240/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.2138 - accuracy: 0.9637 - val_loss: 0.2661 - val_accuracy: 0.9422
# Epoch 241/300
# 83/83 [==============================] - 1s 8ms/step - loss: 0.2128 - accuracy: 0.9633 - val_loss: 0.2653 - val_accuracy: 0.9422
# Epoch 242/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.2117 - accuracy: 0.9633 - val_loss: 0.2646 - val_accuracy: 0.9422
# Epoch 243/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2107 - accuracy: 0.9641 - val_loss: 0.2637 - val_accuracy: 0.9422
# Epoch 244/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2097 - accuracy: 0.9641 - val_loss: 0.2629 - val_accuracy: 0.9422
# Epoch 245/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2087 - accuracy: 0.9641 - val_loss: 0.2621 - val_accuracy: 0.9422
# Epoch 246/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2076 - accuracy: 0.9645 - val_loss: 0.2615 - val_accuracy: 0.9422
# Epoch 247/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2067 - accuracy: 0.9645 - val_loss: 0.2606 - val_accuracy: 0.9443
# Epoch 248/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2056 - accuracy: 0.9652 - val_loss: 0.2599 - val_accuracy: 0.9443
# Epoch 249/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2047 - accuracy: 0.9660 - val_loss: 0.2590 - val_accuracy: 0.9443
# Epoch 250/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2037 - accuracy: 0.9656 - val_loss: 0.2584 - val_accuracy: 0.9443
# Epoch 251/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2027 - accuracy: 0.9664 - val_loss: 0.2576 - val_accuracy: 0.9443
# Epoch 252/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2017 - accuracy: 0.9664 - val_loss: 0.2568 - val_accuracy: 0.9443
# Epoch 253/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.2008 - accuracy: 0.9667 - val_loss: 0.2561 - val_accuracy: 0.9443
# Epoch 254/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1998 - accuracy: 0.9675 - val_loss: 0.2554 - val_accuracy: 0.9443
# Epoch 255/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1989 - accuracy: 0.9675 - val_loss: 0.2546 - val_accuracy: 0.9443
# Epoch 256/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1979 - accuracy: 0.9675 - val_loss: 0.2540 - val_accuracy: 0.9443
# Epoch 257/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1969 - accuracy: 0.9679 - val_loss: 0.2533 - val_accuracy: 0.9443
# Epoch 258/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.1960 - accuracy: 0.9682 - val_loss: 0.2526 - val_accuracy: 0.9443
# Epoch 259/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.1951 - accuracy: 0.9682 - val_loss: 0.2518 - val_accuracy: 0.9465
# Epoch 260/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1942 - accuracy: 0.9682 - val_loss: 0.2512 - val_accuracy: 0.9443
# Epoch 261/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1933 - accuracy: 0.9686 - val_loss: 0.2504 - val_accuracy: 0.9465
# Epoch 262/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.1923 - accuracy: 0.9686 - val_loss: 0.2497 - val_accuracy: 0.9443
# Epoch 263/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1914 - accuracy: 0.9686 - val_loss: 0.2490 - val_accuracy: 0.9422
# Epoch 264/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1905 - accuracy: 0.9682 - val_loss: 0.2484 - val_accuracy: 0.9443
# Epoch 265/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1896 - accuracy: 0.9682 - val_loss: 0.2477 - val_accuracy: 0.9422
# Epoch 266/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1887 - accuracy: 0.9690 - val_loss: 0.2469 - val_accuracy: 0.9443
# Epoch 267/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.1879 - accuracy: 0.9686 - val_loss: 0.2463 - val_accuracy: 0.9422
# Epoch 268/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1869 - accuracy: 0.9690 - val_loss: 0.2456 - val_accuracy: 0.9443
# Epoch 269/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1861 - accuracy: 0.9690 - val_loss: 0.2449 - val_accuracy: 0.9422
# Epoch 270/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1852 - accuracy: 0.9686 - val_loss: 0.2444 - val_accuracy: 0.9422
# Epoch 271/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.1844 - accuracy: 0.9690 - val_loss: 0.2436 - val_accuracy: 0.9422
# Epoch 272/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1835 - accuracy: 0.9694 - val_loss: 0.2428 - val_accuracy: 0.9422
# Epoch 273/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1827 - accuracy: 0.9694 - val_loss: 0.2422 - val_accuracy: 0.9422
# Epoch 274/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1819 - accuracy: 0.9698 - val_loss: 0.2415 - val_accuracy: 0.9422
# Epoch 275/300
# 83/83 [==============================] - 1s 7ms/step - loss: 0.1810 - accuracy: 0.9694 - val_loss: 0.2410 - val_accuracy: 0.9422
# Epoch 276/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.1802 - accuracy: 0.9698 - val_loss: 0.2403 - val_accuracy: 0.9422
# Epoch 277/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.1794 - accuracy: 0.9701 - val_loss: 0.2396 - val_accuracy: 0.9422
# Epoch 278/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.1786 - accuracy: 0.9698 - val_loss: 0.2390 - val_accuracy: 0.9422
# Epoch 279/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.1778 - accuracy: 0.9705 - val_loss: 0.2383 - val_accuracy: 0.9422
# Epoch 280/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.1770 - accuracy: 0.9705 - val_loss: 0.2378 - val_accuracy: 0.9422
# Epoch 281/300
# 83/83 [==============================] - 1s 6ms/step - loss: 0.1762 - accuracy: 0.9709 - val_loss: 0.2373 - val_accuracy: 0.9422
# Epoch 282/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1754 - accuracy: 0.9705 - val_loss: 0.2367 - val_accuracy: 0.9422
# Epoch 283/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1747 - accuracy: 0.9705 - val_loss: 0.2362 - val_accuracy: 0.9443
# Epoch 284/300
# 83/83 [==============================] - 0s 5ms/step - loss: 0.1738 - accuracy: 0.9705 - val_loss: 0.2356 - val_accuracy: 0.9443
# Epoch 285/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1731 - accuracy: 0.9709 - val_loss: 0.2349 - val_accuracy: 0.9443
# Epoch 286/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1724 - accuracy: 0.9709 - val_loss: 0.2344 - val_accuracy: 0.9443
# Epoch 287/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1716 - accuracy: 0.9705 - val_loss: 0.2338 - val_accuracy: 0.9465
# Epoch 288/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1709 - accuracy: 0.9716 - val_loss: 0.2334 - val_accuracy: 0.9465
# Epoch 289/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1702 - accuracy: 0.9713 - val_loss: 0.2327 - val_accuracy: 0.9465
# Epoch 290/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1694 - accuracy: 0.9720 - val_loss: 0.2320 - val_accuracy: 0.9465
# Epoch 291/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1687 - accuracy: 0.9716 - val_loss: 0.2317 - val_accuracy: 0.9465
# Epoch 292/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1680 - accuracy: 0.9716 - val_loss: 0.2311 - val_accuracy: 0.9486
# Epoch 293/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1673 - accuracy: 0.9716 - val_loss: 0.2307 - val_accuracy: 0.9465
# Epoch 294/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1666 - accuracy: 0.9724 - val_loss: 0.2301 - val_accuracy: 0.9486
# Epoch 295/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1659 - accuracy: 0.9720 - val_loss: 0.2296 - val_accuracy: 0.9486
# Epoch 296/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1652 - accuracy: 0.9724 - val_loss: 0.2290 - val_accuracy: 0.9486
# Epoch 297/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1645 - accuracy: 0.9724 - val_loss: 0.2286 - val_accuracy: 0.9486
# Epoch 298/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1638 - accuracy: 0.9724 - val_loss: 0.2282 - val_accuracy: 0.9507
# Epoch 299/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1632 - accuracy: 0.9724 - val_loss: 0.2277 - val_accuracy: 0.9507
# Epoch 300/300
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1625 - accuracy: 0.9724 - val_loss: 0.2272 - val_accuracy: 0.9507

# %% [markdown]
# VISUALIZATION

# %%
# visualize the training acc history
my_acc = history.history['accuracy']
my_val_acc = history.history['val_accuracy']

# plot accuracy
plt.figure(figsize=(8, 8))
plt.subplot(2,1,1)
plt.plot(my_acc, label='Train')
plt.plot(my_val_acc, label='Validation')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

# visualize the loss training history
my_loss = history.history['loss']
my_val_loss = history.history['val_loss']

# plot loss
plt.figure(figsize=(8, 8))
plt.subplot(2,1,1)
plt.plot(my_loss, label='Train')
plt.plot(my_val_loss, label='Validation')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %% [markdown]
# TESTING SESSION

# %%
test_data = pd.read_csv('G:/Semester 8/TA/DWT TA/Win32/Debug/Decompose/test_dataset.csv', header=None).sample(frac=1, random_state=15)
test_frame = test_data.rename({250: 'Class'}, axis=1)
test_frame
# Out:
#            0        1      2      3      4       5       6       7      8  \
# 428 -2.15000 -2.15000 -2.120 -2.050 -1.940 -1.8000 -1.6300 -1.4300 -1.220
# 125  0.21200  0.27300  0.329  0.381  0.428  0.4680  0.5020  0.5310  0.552
# 191 -0.37100 -0.41900 -0.459 -0.489 -0.507 -0.5140 -0.5070 -0.4860 -0.449
# 336 -0.00481  0.05990  0.118  0.170  0.216  0.2550  0.2880  0.3160  0.339
# 524  0.31800  0.30400  0.290  0.277  0.264  0.2540  0.2470  0.2410  0.237
# ..       ...      ...    ...    ...    ...     ...     ...     ...    ...
# 85  -0.12200 -0.00496  0.123  0.262  0.414  0.5780  0.7520  0.9340  1.120
# 199 -2.25000 -2.55000 -2.800 -2.990 -3.110 -3.1700 -3.1700 -3.0900 -2.970
# 156 -0.41700 -0.36200 -0.300 -0.233 -0.162 -0.0897 -0.0178  0.0524  0.120
# 384  0.76500  0.79800  0.828  0.857  0.886  0.9160  0.9460  0.9770  1.010
# 456 -1.60000 -1.46000 -1.300 -1.120 -0.933 -0.7410 -0.5540 -0.3780 -0.215
#
#           9  ...    241    242    243    244     245      246     247    248  \
# 428 -0.9960  ... -0.625 -0.887 -1.130 -1.340 -1.5200 -1.65000 -1.7500 -1.810
# 125  0.5690  ... -0.164 -0.178 -0.199 -0.225 -0.2550 -0.28800 -0.3230 -0.358
# 191 -0.3980  ...  0.459  0.483  0.502  0.516  0.5210  0.51800  0.5060  0.485
# 336  0.3550  ... -1.250 -1.310 -1.350 -1.380 -1.3900 -1.38000 -1.3600 -1.320
# 524  0.2340  ...  0.667  0.716  0.761  0.803  0.8450  0.88800  0.9290  0.970
# ..      ...  ...    ...    ...    ...    ...     ...      ...     ...    ...
# 85   1.3000  ... -0.383 -0.429 -0.468 -0.500 -0.5250 -0.54200 -0.5490 -0.545
# 199 -2.7800  ...  0.165 -0.141 -0.473 -0.825 -1.1900 -1.56000 -1.9200 -2.250
# 156  0.1840  ... -0.373 -0.310 -0.240 -0.165 -0.0873 -0.00763  0.0728  0.152
# 384  1.0300  ... -1.650 -1.630 -1.580 -1.490 -1.3700 -1.22000 -1.0500 -0.850
# 456 -0.0674  ...  0.411  0.489  0.558  0.618  0.6700  0.71600  0.7560  0.794
#
#        249  Class
# 428 -1.810    0.0
# 125 -0.358    1.0
# 191  0.485    1.0
# 336 -1.320    0.0
# 524  0.970    0.0
# ..     ...    ...
# 85  -0.545    1.0
# 199 -2.250    1.0
# 156  0.152    1.0
# 384 -0.850    0.0
# 456  0.794    0.0
#
# [549 rows x 251 columns]

# %%
X_test = test_frame.loc[:, test_frame.columns != 'Class']
Y_test = test_frame.loc[:, test_frame.columns == 'Class']
Y_test = to_categorical(Y_test)

print(X_test.shape)
print(Y_test.shape)
# Out:
# (549, 250)
# (549, 2)

# %%
test_size = test_frame['Class'].value_counts()
plt.pie(test_size, labels=['Normal','Ischemia'], colors=['blue','skyblue'],autopct='%1.1f%%',radius=1.5,textprops={'fontsize': 13})
p=plt.gcf()
plt.show()

# %%
hasil_evaluasi = ann_model.evaluate(X_test, Y_test, batch_size=32)
print()
print("Validation Accuracy: {:.2f}%".format(hasil_evaluasi[1] * 100))
print("    Validation Loss: {:.2f}%".format(hasil_evaluasi[0] * 100))
print()
# Out:
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1333 - accuracy: 0.9617
#
# Validation Accuracy: 96.17%
#     Validation Loss: 13.33%

# %%
Y_pred = ann_model.predict(X_test)
Y_pred = np.argmax(Y_pred,axis=1)
Y_true = np.argmax(Y_test,axis=1)
cm = confusion_matrix(Y_true,Y_pred)
plt.figure()
plot_confusion_matrix(cm, classes=['Normal', 'Ischemia'])
plt.show()
print(classification_report(Y_true,Y_pred))
# Out:
# Confusion matrix, without normalization
# [[202  15]
#  [  6 326]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       217
#            1       0.96      0.98      0.97       332
#
#     accuracy                           0.96       549
#    macro avg       0.96      0.96      0.96       549
# weighted avg       0.96      0.96      0.96       549

# %% [markdown]
# SAVED MODEL

# %%
model_file_name = 'decompose_model'
c_model_name = 'decompose_model'
ann_model.save(model_file_name + '.h5')

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(ann_model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()

open(model_file_name + '.tflite', 'wb').write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ACHMAD~1\AppData\Local\Temp\tmpun3dwo3x\assets
# INFO:tensorflow:Assets written to: C:\Users\ACHMAD~1\AppData\Local\Temp\tmpun3dwo3x\assets
# 13536

# %%
# Function: Convert some hex value into an array for C programming
def hex_to_c_array(hex_data, var_name):
  c_str = ''

  # Create header guard
  c_str += '#ifndef ' + var_name.upper() + '_H\n'
  c_str += '#define ' + var_name.upper() + '_H\n\n'

  # Add array length at top of file
  c_str += '\nunsigned int ' + var_name + '_len = ' + str(len(hex_data)) + ';\n'

  # Declare C variable
  c_str += 'unsigned char ' + var_name + '[] = {'
  hex_array = []
  for i, val in enumerate(hex_data) :

    # Construct string from hex
    hex_str = format(val, '#04x')

    # Add formatting so each line stays within 80 characters
    if (i + 1) < len(hex_data):
      hex_str += ','
    if (i + 1) % 12 == 0:
      hex_str += '\n '
    hex_array.append(hex_str)

  # Add closing brace
  c_str += '\n ' + format(' '.join(hex_array)) + '\n};\n\n'

  # Close out header guard
  c_str += '#endif //' + var_name.upper() + '_H'

  return c_str

# %%
# Write TFLite model to a C source (or header) file
with open(c_model_name + '.h', 'w') as file:
  file.write(hex_to_c_array(tflite_model, c_model_name))
